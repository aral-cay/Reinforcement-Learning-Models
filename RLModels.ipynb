# %%
#PSYC 51 Final Project - Aral Cay

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.stats import pearsonr, spearmanr, chi2_contingency, mannwhitneyu, ttest_ind, ttest_1samp, probplot
from tqdm import trange, tqdm
import os
import pickle

# for run l analysis
from pathlib import Path

## Setup

# random seed
RNG = np.random.default_rng(123)

# styling
plt.rcParams.update({
    "figure.figsize": (6, 4),
    "axes.grid": True,
    "grid.alpha": 0.3,
    "font.size": 12
})

# config
CFG = dict(
    n_trials_tab = 300,
    n_trials_dawh = 300,
    n_datasets   = 24,
    rw_restarts  = 6,
    sp_restarts  = 10,
)

print("Configuration:", CFG)
os.makedirs("figs", exist_ok=True)

# data indices given in dataset descriptiokn
DATASET_TO_TASK = {
    0: "DAWH",
    1: "TAB",
    2: "TAB",
    3: "DAWH",
    4: "DAWH",
    5: "TAB"
}

# load shin data
def load_shin_data(pkl_path="shin_data.pkl"):

    try:
        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        for idx in range(len(data)):
            task = DATASET_TO_TASK.get(idx, "UNKNOWN")
            n_sessions = len(data[idx]) if hasattr(data[idx], '__len__') else 0
            print(f"  Dataset {idx}: {task} task, {n_sessions} sessions")
        return data


    except FileNotFoundError:
        print(f"file not found")
        return None

    except Exception as e:
        print(f"Error")
        return None

# extract session data
def extract_session_data(data, dataset_idx, session_idx):

    if data is None:
        return None, None, None

    task_type = DATASET_TO_TASK.get(dataset_idx, None)

    if task_type is None:
        return None, None, None

    try:

        session_data = data[dataset_idx][session_idx]
        choices, rewards = get_choices_rewards(session_data)
        return choices, rewards, task_type

    except (IndexError, KeyError, TypeError) as e:
        print("Error")
        return None, None, None

# Helper functions
def aic(ll, k, n):
    return 2 * k - 2 * ll

def bic(ll, k, n):
    return k * np.log(max(n, 1)) - 2 * ll

def softmax_prob(a_left, a_right, beta):
    r_diff = a_left - a_right
    x = np.clip(-beta * r_diff, -50, 50)
    return 1.0 / (1.0 + np.exp(-x))

#Stacking param for sp
def compute_stack_parameter(a_est, run_length):

    if a_est <= 1e-10:
        return run_length + 1.0
    one_minus_a = 1.0 - a_est
    if abs(one_minus_a - 1.0) < 1e-10:
        return run_length + 1.0
    return (1.0 - one_minus_a ** (run_length + 1)) / a_est

# env funcs
def simulate_env_TAB_prob(t, block_len=40, high=0.8, low=0.2):
    b = (t // block_len) % 2
    return (high, low) if b == 0 else (low, high)

def daw_prob(base, inc, since, max_p):

    return min(max_p, base + inc * since)

# RW model simulation
def simulate_RW(alpha, beta, n_trials=200, task="TAB", **task_kwargs):

    A_L, A_R = 0.5, 0.5
    choices = np.zeros(n_trials, dtype=int)
    rewards = np.zeros(n_trials, dtype=int)

    base = task_kwargs.get("base", 0.05)
    inc = task_kwargs.get("inc", 0.08)
    max_p = task_kwargs.get("max_p", 0.95)
    block_len = task_kwargs.get("block_len", 40)
    high, low = 0.8, 0.2
    since_L, since_R = 0, 0

    for t in range(n_trials):
        p_right = softmax_prob(A_L, A_R, beta)
        a = RNG.binomial(1, p_right)
        choices[t] = a

        if task == "TAB":
            pL, pR = simulate_env_TAB_prob(t, block_len, high, low)
        elif task == "DAWH":
            pL = daw_prob(base, inc, since_L, max_p)
            pR = daw_prob(base, inc, since_R, max_p)
        else:
            raise ValueError("Value error")



        p = pR if a == 1 else pL
        r = RNG.binomial(1, p)
        rewards[t] = r

        if a == 0:
            A_L = (1.0 - alpha) * A_L + alpha * r
            since_L = 0
            since_R += 1

        else:
            A_R = (1.0 - alpha) * A_R + alpha * r
            since_R = 0
            since_L += 1

    return choices, rewards


# log likelihood for rw model
def loglik_RW(alpha, beta, choices, rewards):

    A_L, A_R = 0.5, 0.5
    ll = 0.0

    for a, r in zip(choices, rewards):
        p_right = softmax_prob(A_L, A_R, beta)
        p = p_right if a == 1 else (1.0 - p_right)
        p = np.clip(p, 1e-12, 1.0 - 1e-12)
        ll += np.log(p)

        if a == 0:
            A_L = (1.0 - alpha) * A_L + alpha * r
        else:
            A_R = (1.0 - alpha) * A_R + alpha * r
    return ll

# SP model
def simulate_SP(alpha, beta, n_trials=200, task="DAWH", **task_kwargs):

    A_L, A_R = 0.5, 0.5
    choices = np.zeros(n_trials, dtype=int)
    rewards = np.zeros(n_trials, dtype=int)

    base = task_kwargs.get("base", 0.05)
    inc = task_kwargs.get("inc", 0.08)
    max_p = task_kwargs.get("max_p", 0.95)
    block_len = task_kwargs.get("block_len", 40)
    high, low = 0.8, 0.2
    run_length_L = 0
    run_length_R = 0

    for t in range(n_trials):

        X_L = compute_stack_parameter(A_L, run_length_R)
        X_R = compute_stack_parameter(A_R, run_length_L)

        S_L = A_L * X_L
        S_R = A_R * X_R

        p_right = softmax_prob(S_L, S_R, beta)
        a = RNG.binomial(1, p_right)
        choices[t] = a

        if task == "TAB":
            pL, pR = simulate_env_TAB_prob(t, block_len, high, low)

        elif task == "DAWH":
            since_L = run_length_R
            since_R = run_length_L
            pL = daw_prob(base, inc, since_L, max_p)
            pR = daw_prob(base, inc, since_R, max_p)

        else:
            raise ValueError("Value Error")

        # reward
        p = pR if a == 1 else pL
        r = RNG.binomial(1, p)
        rewards[t] = r

        if a == 0:

            A_L = (1.0 - alpha) * A_L + (alpha / X_L) * r
            run_length_L += 1
            run_length_R = 0
        else:

            A_R = (1.0 - alpha) * A_R + (alpha / X_R) * r
            run_length_R += 1
            run_length_L = 0


    return choices, rewards

# log likelihood SP model
def loglik_SP(alpha, beta, choices, rewards):

    A_L, A_R = 0.5, 0.5
    run_length_L = 0
    run_length_R = 0
    ll = 0.0

    for a, r in zip(choices, rewards):

        X_L = compute_stack_parameter(A_L, run_length_R)
        X_R = compute_stack_parameter(A_R, run_length_L)

        S_L = A_L * X_L

        S_R = A_R * X_R


        p_right = softmax_prob(S_L, S_R, beta)
        p = p_right if a == 1 else (1.0 - p_right)
        p = np.clip(p, 1e-12, 1.0 - 1e-12)
        ll += np.log(p)

        if a == 0:
            A_L = (1.0 - alpha) * A_L + (alpha / X_L) * r
            run_length_L += 1
            run_length_R = 0
        else:
            A_R = (1.0 - alpha) * A_R + (alpha / X_R) * r
            run_length_R += 1
            run_length_L = 0


    return ll

# RW Fit function
def fit_RW(choices, rewards, n_restarts=None, show_progress=False):
    if n_restarts is None:
        n_restarts = CFG["rw_restarts"]

    best = None
    n = len(choices)
    bounds = [(1e-4, 1.0), (0.5, 50.0)]

    def nll(theta):
        a, b = theta
        return -loglik_RW(a, b, choices, rewards)

    restart_range = tqdm(range(n_restarts), desc="Fitting RW", leave=False, disable=not show_progress)

    for _ in restart_range:
        x0 = np.array([RNG.uniform(0.05, 0.6),
                       RNG.uniform(1.0, 10.0)])
        res = minimize(nll, x0, bounds=bounds, method="L-BFGS-B")
        if (best is None) or (res.fun < best["fun"]):
            best = {"x": res.x, "fun": res.fun}

    alpha, beta = best["x"]
    ll = -best["fun"]
    k = 2
    return dict(

        model="RW",
        alpha=float(alpha), beta=float(beta),
        ll=float(ll), k=k,
        AIC=float(aic(ll, k, n)),
        BIC=float(bic(ll, k, n))

    )

#Fit SP function
def fit_SP(choices, rewards, n_restarts=None, show_progress=False):

    if n_restarts is None:
        n_restarts = CFG["sp_restarts"]

    best = None
    n = len(choices)
    # alpha and beta bounds
    bounds = [(1e-4, 1.0 - 1e-4), (0.5, 15.0)]

    def nll(theta):
        a, b = theta
        return -loglik_SP(a, b, choices, rewards)

    restart_range = tqdm(range(n_restarts), desc="Fitting SP", leave=False, disable=not show_progress)

    for _ in restart_range:

        x0 = np.array([RNG.uniform(0.05, 0.6),
                       RNG.uniform(1.0, 10.0)])

        res = minimize(nll, x0, bounds=bounds, method="L-BFGS-B",
                       options={"maxiter": 600, "ftol": 1e-9})

        if (best is None) or (res.fun < best["fun"]):
            best = {"x": res.x, "fun": res.fun}


    alpha, beta = best["x"]
    ll = -best["fun"]
    k = 2

    return dict(
        model="SP",
        alpha=float(alpha), beta=float(beta),
        ll=float(ll), k=k,
        AIC=float(aic(ll, k, n)),
        BIC=float(bic(ll, k, n))
    )
# Out:
# Configuration: {'n_trials_tab': 300, 'n_trials_dawh': 300, 'n_datasets': 24, 'rw_restarts': 6, 'sp_restarts': 10}

# %%
# parameter recovery

def param_recovery_single(model_name, true_params_list, n_subj=4, n_trials=260,
                          task=None, task_kwargs=None):

    if task_kwargs is None:
        task_kwargs = {}


    T, R = [], []
    pbar = trange(len(true_params_list) * n_subj, desc=f"ParamRecovery {model_name}")

    for params in true_params_list:

        for _ in range(n_subj):

            if model_name == "RW":
                a, b = params
                ch, rw = simulate_RW(a, b, n_trials=n_trials, task=task, **task_kwargs)
                fit = fit_RW(ch, rw)
                T.append([a, b])
                R.append([fit["alpha"], fit["beta"]])

            elif model_name == "SP":
                a, b = params
                ch, rw = simulate_SP(a, b, n_trials=n_trials, task=task, **task_kwargs)
                fit = fit_SP(ch, rw)
                T.append([a, b])
                R.append([fit["alpha"], fit["beta"]])

            else:
                raise ValueError("Value Error")
            pbar.update(1)

    pbar.close()
    return np.array(T), np.array(R)


# param recocery analysis
def compact_param_recovery_summary():

    print("\nParameter Recovery Analysis\n")


    # Parameter grids to test
    RW_TRUE = [(a, b)
               for a in np.linspace(0.15, 0.60, 3)
               for b in (1.5, 4.0, 8.0)]


    SP_TRUE = [(a, b)
               for a in np.linspace(0.15, 0.60, 3)
               for b in (1.5, 4.0, 8.0)]

    print("\nRecovering RW parameters - TAB task")
    T_rw, R_rw = param_recovery_single(
        "RW", RW_TRUE, n_trials=300, task="TAB", task_kwargs={"block_len": 40}
    )


    print("Recovering SP parameters - DAWH task")
    T_sp, R_sp = param_recovery_single(
        "SP", SP_TRUE, n_trials=300, task="DAWH",
        task_kwargs={"base": 0.02, "inc": 0.12, "max_p": 0.98}
    )

    def rstr(true, fit):
        r, _ = pearsonr(true, fit)
        return r

    r_rw_a = rstr(T_rw[:, 0], R_rw[:, 0])
    r_rw_b = rstr(T_rw[:, 1], R_rw[:, 1])


    r_sp_a = rstr(T_sp[:, 0], R_sp[:, 0])
    r_sp_b = rstr(T_sp[:, 1], R_sp[:, 1])

    fig, axes = plt.subplots(2, 2, figsize=(10, 8))
    axes = axes.ravel()

    def panel(ax, x, y, title):

        lo = float(min(x.min(), y.min()))
        hi = float(max(x.max(), y.max()))

        ax.scatter(x, y, s=16, alpha=0.8)
        ax.plot([lo, hi], [lo, hi], '--', linewidth=1)

        ax.set_xlabel("True")
        ax.set_ylabel("Recovered")
        ax.set_title(title)

    panel(axes[0], T_rw[:, 0], R_rw[:, 0], f"RW alpha -> r = {r_rw_a:.2f})")
    panel(axes[1], T_rw[:, 1], R_rw[:, 1], f"RW beta -> r = {r_rw_b:.2f})")

    panel(axes[2], T_sp[:, 0], R_sp[:, 0], f"SP alpha -> r = {r_sp_a:.2f})")
    panel(axes[3], T_sp[:, 1], R_sp[:, 1], f"SP beta -> r = {r_sp_b:.2f})")

    fig.tight_layout()
    fname = "figs/parameter_recovery.png"
    fig.savefig(fname, dpi=220, bbox_inches="tight")
    plt.show()
    print(f"\nSaved: {fname}")
    print(f"\nParameter recovery correlations - pearson r:\n")
    print(f"RW alpha: {r_rw_a:.3f} | RW beta: {r_rw_b:.3f}")
    print(f"SP alpha: {r_sp_a:.3f} | SP beta: {r_sp_b:.3f}")



compact_param_recovery_summary()
# Out:
# Parameter Recovery Analysis
#
#
# Recovering RW parameters - TAB task
# ParamRecovery RW: 100%|██████████| 36/36 [00:41<00:00,  1.15s/it]
# Recovering SP parameters - DAWH task
# ParamRecovery SP: 100%|██████████| 36/36 [01:34<00:00,  2.61s/it]
# Saved: figs/parameter_recovery.png
#
# Parameter recovery correlations - pearson r:
#
# RW alpha: 0.888 | RW beta: 0.923
# SP alpha: 0.745 | SP beta: 0.903

# %%
## Model Recovery

# confusion matrix
def confusion(true_labels, pred_labels, labels=("RW", "SP")):

    M = np.zeros((2, 2), dtype=int)
    idx = {lab: i for i, lab in enumerate(labels)}


    for t, p in zip(true_labels, pred_labels):
        M[idx[t], idx[p]] += 1
    return M

# plot cm
def plot_cm(cm, title):

    plt.figure()
    plt.imshow(cm, vmin=0, vmax=cm.max(), cmap="viridis")

    for i in range(2):
        for j in range(2):
            plt.text(j, i, str(cm[i, j]), ha='center', va='center', color="white")

    plt.xticks([0, 1], ["Pred RW", "Pred SP"])
    plt.yticks([0, 1], ["True RW", "True SP"])
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    fname = "figs/" + title.replace(" ", "_").replace("—", "-") + ".png"
    plt.savefig(fname, dpi=220, bbox_inches="tight")
    plt.show()


# model recovery test for a given task
def model_recovery_same_task(task, n_datasets=None, n_trials=None):

    assert task in ("TAB", "DAWH")

    if n_datasets is None:
        n_datasets = CFG["n_datasets"]

    if n_trials is None:
        n_trials = CFG["n_trials_tab"] if task == "TAB" else CFG["n_trials_dawh"]

    if task == "TAB":
        env = {"block_len": 40}
    else:
        env = {"base": 0.02, "inc": 0.12, "max_p": 0.98}

    true_labels, pred_AIC, pred_BIC = [], [], []
    pbar = trange(n_datasets, desc=f"ModelRec[{task}]")

    for i in range(n_datasets):
        gen_is_rw = (i < n_datasets // 2)

        if gen_is_rw:
            if task == "TAB":
                a = RNG.uniform(0.20, 0.55)
                b = RNG.uniform(3.0, 8.0)

            else:
                a = RNG.uniform(0.15, 0.50)
                b = RNG.uniform(2.0, 7.0)

            ch, rw = simulate_RW(a, b, n_trials=n_trials, task=task, **env)
            true_labels.append("RW")

        else:
            if task == "TAB":
                a = RNG.uniform(0.15, 0.45)
                b = RNG.uniform(2.0, 7.0)

            else:
                a = RNG.uniform(0.15, 0.50)
                b = RNG.uniform(2.0, 7.0)

            ch, rw = simulate_SP(a, b, n_trials=n_trials, task=task, **env)
            true_labels.append("SP")

        frw = fit_RW(ch, rw)
        fsp = fit_SP(ch, rw)

        pred_AIC.append("RW" if frw["AIC"] < fsp["AIC"] else "SP")
        pred_BIC.append("RW" if frw["BIC"] < fsp["BIC"] else "SP")

        pbar.update(1)

    pbar.close()
    return np.array(true_labels), np.array(pred_AIC), np.array(pred_BIC)

# run analysis
print("\nModel Recovery Analysis\n")


print("\nTAB Task:\n")
true_tab, aic_tab, bic_tab = model_recovery_same_task("TAB")
cm_tab_aic = confusion(true_tab, aic_tab)
cm_tab_bic = confusion(true_tab, bic_tab)
print("\nTAB AIC confusion matrix:\n", cm_tab_aic)
print("\nTAB BIC confusion matrix:\n", cm_tab_bic)
plot_cm(cm_tab_aic, "Model Recovery (AIC) - TAB")
plot_cm(cm_tab_bic, "Model Recovery (BIC) - TAB")

tab_aic_acc = np.trace(cm_tab_aic) / np.sum(cm_tab_aic)
tab_bic_acc = np.trace(cm_tab_bic) / np.sum(cm_tab_bic)
print(f"\nTAB Task Recovery Accuracy:\n")
print(f"AIC: {tab_aic_acc*100:.1f}%")
print(f"BIC: {tab_bic_acc*100:.1f}%")

print("\nDAWH Task:\n")
true_dawh, aic_dawh, bic_dawh = model_recovery_same_task("DAWH")
cm_dawh_aic = confusion(true_dawh, aic_dawh)
cm_dawh_bic = confusion(true_dawh, bic_dawh)

print("\nDAWH AIC confusion matrix:\n", cm_dawh_aic)
print("\nDAWH BIC confusion matrix:\n", cm_dawh_bic)
plot_cm(cm_dawh_aic, "Model Recovery (AIC) - DAWH")
plot_cm(cm_dawh_bic, "Model Recovery (BIC) - DAWH")

dawh_aic_acc = np.trace(cm_dawh_aic) / np.sum(cm_dawh_aic)
dawh_bic_acc = np.trace(cm_dawh_bic) / np.sum(cm_dawh_bic)
print(f"\nDAWH Task Recovery Accuracy:")
print(f"AIC: {dawh_aic_acc*100:.1f}%")
print(f"BIC: {dawh_bic_acc*100:.1f}%")
# Out:
# Model Recovery Analysis
#
#
# TAB Task:
# ModelRec[TAB]: 100%|██████████| 24/24 [01:19<00:00,  3.31s/it]
# TAB AIC confusion matrix:
#  [[12  0]
#  [ 0 12]]
#
# TAB BIC confusion matrix:
#  [[12  0]
#  [ 0 12]]
# TAB Task Recovery Accuracy:
#
# AIC: 100.0%
# BIC: 100.0%
#
# DAWH Task:
# ModelRec[DAWH]: 100%|██████████| 24/24 [01:48<00:00,  4.52s/it]
# DAWH AIC confusion matrix:
#  [[11  1]
#  [ 0 12]]
#
# DAWH BIC confusion matrix:
#  [[11  1]
#  [ 0 12]]
# DAWH Task Recovery Accuracy:
# AIC: 95.8%
# BIC: 95.8%

# %%
# Fit Models to Shin Data

# get the choices rewards
def get_choices_rewards(session):

    arr = np.asarray(session)

    if arr.ndim == 2 and arr.shape[1] >= 2:

        choices = arr[:, 0].astype(int)
        rewards = arr[:, 1].astype(int)

    elif arr.ndim == 2 and arr.shape[0] >= 2:
        choices = arr[0].astype(int)
        rewards = arr[1].astype(int)

    else:
        raise ValueError("Value Error")
    return choices, rewards

def analyze_real_data(pkl_path="shin_data.pkl"):
    data = load_shin_data(pkl_path)
    if data is None:
        return None

    results = []

    print("\nFitting models..")

    total_sessions = sum(len(data[i]) if hasattr(data[i], '__len__') else 0
                        for i in range(len(data)))

    #this lib is great for progres bars, USE IT IN FUTURE PROJECTS
    main_pbar = tqdm(total=total_sessions, desc="Processing sessions", unit="session")

    for dataset_idx in range(len(data)):
        task_type = DATASET_TO_TASK.get(dataset_idx, "UNKNOWN")
        n_sessions = len(data[dataset_idx]) if hasattr(data[dataset_idx], '__len__') else 0

        dataset_pbar = tqdm(range(n_sessions),
                           desc=f"Dataset {dataset_idx} ({task_type})",
                           leave=False, unit="session")

        for session_idx in dataset_pbar:
            choices, rewards, task = extract_session_data(data, dataset_idx, session_idx)

            if choices is None or rewards is None:
                continue

            choices = np.array(choices)
            rewards = np.array(rewards)

            if len(choices) == 0 or len(choices) != len(rewards):
                continue

            try:

                frw = fit_RW(choices, rewards, show_progress=False)
                fsp = fit_SP(choices, rewards, show_progress=False)

                winner_AIC = "RW" if frw["AIC"] < fsp["AIC"] else "SP"
                winner_BIC = "RW" if frw["BIC"] < fsp["BIC"] else "SP"

                results.append({
                    "dataset_idx": dataset_idx,
                    "task": task,
                    "session_idx": session_idx,
                    "n_trials": len(choices),
                    "rw_alpha": frw["alpha"],
                    "rw_beta": frw["beta"],
                    "rw_ll": frw["ll"],
                    "rw_AIC": frw["AIC"],
                    "rw_BIC": frw["BIC"],
                    "sp_alpha": fsp["alpha"],
                    "sp_beta": fsp["beta"],
                    "sp_ll": fsp["ll"],
                    "sp_AIC": fsp["AIC"],
                    "sp_BIC": fsp["BIC"],
                    "winner_AIC": winner_AIC,
                    "winner_BIC": winner_BIC,
                    "AIC_diff": fsp["AIC"] - frw["AIC"],
                    "BIC_diff": fsp["BIC"] - frw["BIC"],
                    "delta_ll": fsp["ll"] - frw["ll"],
                })


                dataset_pbar.set_postfix({"fitted": len(results)})
                main_pbar.update(1)

            except Exception as e:
                dataset_pbar.write(f"Error fitting session {session_idx}: {e}")
                main_pbar.update(1)
                continue

        dataset_pbar.close()

    main_pbar.close()

    if len(results) == 0:
        return None

    df = pd.DataFrame(results)


    # Parameter summaries by task
    print("\nParameter values by task:")
    for task in ['TAB', 'DAWH']:

        task_df = df[df['task'] == task]

        if len(task_df) > 0:

            print(f"\n{task} task (n={len(task_df)} sessions):")
            print(f"RW Alpha: M={task_df['rw_alpha'].mean():.3f}, SD={task_df['rw_alpha'].std():.3f}")
            print(f"RW Beta:  M={task_df['rw_beta'].mean():.3f}, SD={task_df['rw_beta'].std():.3f}")
            print(f"SP Alpha: M={task_df['sp_alpha'].mean():.3f}, SD={task_df['sp_alpha'].std():.3f}")
            print(f"SP Beta:  M={task_df['sp_beta'].mean():.3f}, SD={task_df['sp_beta'].std():.3f}")

    # param distribution
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))

    ax = axes[0, 0]
    for task in ['TAB', 'DAWH']:

        task_df = df[df['task'] == task]

        if len(task_df) > 0:
            ax.hist(task_df['rw_alpha'], alpha=0.6, label=f'{task} (n={len(task_df)})', bins=20)

    ax.set_xlabel('RW Alpha')
    ax.set_ylabel('Frequency')
    ax.set_title('RW Alpha Distribution by Task')
    ax.legend()
    ax.grid(True, alpha=0.3)

    ax = axes[0, 1]

    for task in ['TAB', 'DAWH']:
        task_df = df[df['task'] == task]
        if len(task_df) > 0:
            ax.hist(task_df['rw_beta'], alpha=0.6, label=f'{task} (n={len(task_df)})', bins=20)

    ax.set_xlabel('RW Beta')
    ax.set_ylabel('Frequency')
    ax.set_title('RW Beta Distribution by Task')
    ax.legend()
    ax.grid(True, alpha=0.3)

    ax = axes[1, 0]
    for task in ['TAB', 'DAWH']:
        task_df = df[df['task'] == task]
        if len(task_df) > 0:
            ax.hist(task_df['sp_alpha'], alpha=0.6, label=f'{task} (n={len(task_df)})', bins=20)

    ax.set_xlabel('SP Alpha')
    ax.set_ylabel('Frequency')
    ax.set_title('SP Alpha Distribution by Task')
    ax.legend()
    ax.grid(True, alpha=0.3)

    ax = axes[1, 1]

    for task in ['TAB', 'DAWH']:
        task_df = df[df['task'] == task]
        if len(task_df) > 0:
            ax.hist(task_df['sp_beta'], alpha=0.6, label=f'{task} (n={len(task_df)})', bins=20)
    ax.set_xlabel('SP Beta')
    ax.set_ylabel('Frequency')
    ax.set_title('SP Beta Distribution by Task')
    ax.legend()
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    fname = "figs/parameter_distributions_by_task.png"
    plt.savefig(fname, dpi=220, bbox_inches="tight")
    plt.show()

    # Model comparison
    print("\nModel comparison res:")


    tab_rw = (df[df['task'] == 'TAB']['winner_AIC'] == 'RW').sum()
    tab_sp = (df[df['task'] == 'TAB']['winner_AIC'] == 'SP').sum()

    dawh_rw = (df[df['task'] == 'DAWH']['winner_AIC'] == 'RW').sum()
    dawh_sp = (df[df['task'] == 'DAWH']['winner_AIC'] == 'SP').sum()

    contingency_table = np.array([[tab_rw, tab_sp],
                                  [dawh_rw, dawh_sp]])

    print(f"\nContingency Table (AIC):")
    print(f"              RW wins  SP wins")
    print(f"TAB task:     {tab_rw:4d}    {tab_sp:4d}")
    print(f"DAWH task:    {dawh_rw:4d}    {dawh_sp:4d}")

    chi2, p_chi2, dof, expected = chi2_contingency(contingency_table)
    print(f"\nChi-square test: chi^2 = {chi2:.4f}, p = {p_chi2:.4f}")


    output_path = "figs/parameter_fitting_results.csv"
    df.to_csv(output_path, index=False)
    print(f"\nSaved results to: {output_path}")

    return df

real_data_results = analyze_real_data()
# Out:
#   Dataset 0: DAWH task, 49 sessions
#   Dataset 1: TAB task, 32 sessions
#   Dataset 2: TAB task, 122 sessions
#   Dataset 3: DAWH task, 38 sessions
#   Dataset 4: DAWH task, 81 sessions
#   Dataset 5: TAB task, 61 sessions
#
# Fitting models..
# Processing sessions:   0%|          | 0/383 [00:00<?, ?session/s]
# Dataset 0 (DAWH):   0%|          | 0/49 [00:00<?, ?session/s]
# Processing sessions:   0%|          | 1/383 [00:01<08:29,  1.33s/session]
# Dataset 0 (DAWH):   2%|▏         | 1/49 [00:01<01:04,  1.33s/session, fitted=1]
# Processing sessions:   1%|          | 2/383 [00:02<09:23,  1.48s/session]
# Dataset 0 (DAWH):   4%|▍         | 2/49 [00:02<01:09,  1.48s/session, fitted=2]
# Processing sessions:   1%|          | 3/383 [00:04<08:45,  1.38s/session]
# Dataset 0 (DAWH):   6%|▌         | 3/49 [00:04<01:03,  1.38s/session, fitted=3]
# Processing sessions:   1%|          | 4/383 [00:05<08:51,  1.40s/session]
# Dataset 0 (DAWH):   8%|▊         | 4/49 [00:05<01:03,  1.40s/session, fitted=4]
# Processing sessions:   1%|▏         | 5/383 [00:07<10:00,  1.59s/session]
# Dataset 0 (DAWH):  10%|█         | 5/49 [00:07<01:09,  1.59s/session, fitted=5]
# Processing sessions:   2%|▏         | 6/383 [00:09<11:16,  1.79s/session]
# Dataset 0 (DAWH):  12%|█▏        | 6/49 [00:09<01:17,  1.79s/session, fitted=6]
# Processing sessions:   2%|▏         | 7/383 [00:12<12:42,  2.03s/session]
# Dataset 0 (DAWH):  14%|█▍        | 7/49 [00:12<01:25,  2.03s/session, fitted=7]
# Processing sessions:   2%|▏         | 8/383 [00:14<12:51,  2.06s/session]
# Dataset 0 (DAWH):  16%|█▋        | 8/49 [00:14<01:24,  2.06s/session, fitted=8]
# Processing sessions:   2%|▏         | 9/383 [00:16<12:56,  2.08s/session]
# Dataset 0 (DAWH):  18%|█▊        | 9/49 [00:16<01:23,  2.08s/session, fitted=9]
# Processing sessions:   3%|▎         | 10/383 [00:17<11:11,  1.80s/session]
# Dataset 0 (DAWH):  20%|██        | 10/49 [00:17<01:10,  1.80s/session, fitted=10]
# Processing sessions:   3%|▎         | 11/383 [00:19<12:01,  1.94s/session]
# Dataset 0 (DAWH):  22%|██▏       | 11/49 [00:19<01:13,  1.94s/session, fitted=11]
# Processing sessions:   3%|▎         | 12/383 [00:21<10:46,  1.74s/session]
# Dataset 0 (DAWH):  24%|██▍       | 12/49 [00:21<01:04,  1.74s/session, fitted=12]
# Processing sessions:   3%|▎         | 13/383 [00:22<10:17,  1.67s/session]
# Dataset 0 (DAWH):  27%|██▋       | 13/49 [00:22<01:00,  1.67s/session, fitted=13]
# Processing sessions:   4%|▎         | 14/383 [00:23<09:25,  1.53s/session]
# Dataset 0 (DAWH):  29%|██▊       | 14/49 [00:23<00:53,  1.53s/session, fitted=14]
# Processing sessions:   4%|▍         | 15/383 [00:26<10:50,  1.77s/session]
# Dataset 0 (DAWH):  31%|███       | 15/49 [00:26<01:00,  1.77s/session, fitted=15]
# Processing sessions:   4%|▍         | 16/383 [00:27<10:30,  1.72s/session]
# Dataset 0 (DAWH):  33%|███▎      | 16/49 [00:27<00:56,  1.72s/session, fitted=16]
# Processing sessions:   4%|▍         | 17/383 [00:29<10:56,  1.79s/session]
# Dataset 0 (DAWH):  35%|███▍      | 17/49 [00:29<00:57,  1.79s/session, fitted=17]
# Processing sessions:   5%|▍         | 18/383 [00:31<11:25,  1.88s/session]
# Dataset 0 (DAWH):  37%|███▋      | 18/49 [00:31<00:58,  1.88s/session, fitted=18]
# Processing sessions:   5%|▍         | 19/383 [00:34<11:53,  1.96s/session]
# Dataset 0 (DAWH):  39%|███▉      | 19/49 [00:34<00:58,  1.96s/session, fitted=19]
# Processing sessions:   5%|▌         | 20/383 [00:35<10:58,  1.81s/session]
# Dataset 0 (DAWH):  41%|████      | 20/49 [00:35<00:52,  1.81s/session, fitted=20]
# Processing sessions:   5%|▌         | 21/383 [00:37<10:32,  1.75s/session]
# Dataset 0 (DAWH):  43%|████▎     | 21/49 [00:37<00:48,  1.75s/session, fitted=21]
# Processing sessions:   6%|▌         | 22/383 [00:39<10:49,  1.80s/session]
# Dataset 0 (DAWH):  45%|████▍     | 22/49 [00:39<00:48,  1.80s/session, fitted=22]
# Processing sessions:   6%|▌         | 23/383 [00:40<10:00,  1.67s/session]
# Dataset 0 (DAWH):  47%|████▋     | 23/49 [00:40<00:43,  1.67s/session, fitted=23]
# Processing sessions:   6%|▋         | 24/383 [00:41<09:22,  1.57s/session]
# Dataset 0 (DAWH):  49%|████▉     | 24/49 [00:41<00:39,  1.57s/session, fitted=24]
# Processing sessions:   7%|▋         | 25/383 [00:44<10:46,  1.81s/session]
# Dataset 0 (DAWH):  51%|█████     | 25/49 [00:44<00:43,  1.81s/session, fitted=25]
# Processing sessions:   7%|▋         | 26/383 [00:45<09:47,  1.65s/session]
# Dataset 0 (DAWH):  53%|█████▎    | 26/49 [00:45<00:37,  1.65s/session, fitted=26]
# Processing sessions:   7%|▋         | 27/383 [00:47<09:52,  1.66s/session]
# Dataset 0 (DAWH):  55%|█████▌    | 27/49 [00:47<00:36,  1.66s/session, fitted=27]
# Processing sessions:   7%|▋         | 28/383 [00:48<10:14,  1.73s/session]
# Dataset 0 (DAWH):  57%|█████▋    | 28/49 [00:48<00:36,  1.73s/session, fitted=28]
# Processing sessions:   8%|▊         | 29/383 [00:50<10:18,  1.75s/session]
# Dataset 0 (DAWH):  59%|█████▉    | 29/49 [00:50<00:34,  1.75s/session, fitted=29]
# Processing sessions:   8%|▊         | 30/383 [00:52<11:05,  1.89s/session]
# Dataset 0 (DAWH):  61%|██████    | 30/49 [00:52<00:35,  1.89s/session, fitted=30]
# Processing sessions:   8%|▊         | 31/383 [00:54<10:53,  1.86s/session]
# Dataset 0 (DAWH):  63%|██████▎   | 31/49 [00:54<00:33,  1.86s/session, fitted=31]
# Processing sessions:   8%|▊         | 32/383 [00:56<10:02,  1.72s/session]
# Dataset 0 (DAWH):  65%|██████▌   | 32/49 [00:56<00:29,  1.72s/session, fitted=32]
# Processing sessions:   9%|▊         | 33/383 [00:57<09:08,  1.57s/session]
# Dataset 0 (DAWH):  67%|██████▋   | 33/49 [00:57<00:25,  1.57s/session, fitted=33]
# Processing sessions:   9%|▉         | 34/383 [00:59<09:41,  1.67s/session]
# Dataset 0 (DAWH):  69%|██████▉   | 34/49 [00:59<00:24,  1.67s/session, fitted=34]
# Processing sessions:   9%|▉         | 35/383 [01:01<09:59,  1.72s/session]
# Dataset 0 (DAWH):  71%|███████▏  | 35/49 [01:01<00:24,  1.72s/session, fitted=35]
# Processing sessions:   9%|▉         | 36/383 [01:03<11:09,  1.93s/session]
# Dataset 0 (DAWH):  73%|███████▎  | 36/49 [01:03<00:25,  1.93s/session, fitted=36]
# Processing sessions:  10%|▉         | 37/383 [01:05<12:02,  2.09s/session]
# Dataset 0 (DAWH):  76%|███████▌  | 37/49 [01:05<00:25,  2.09s/session, fitted=37]
# Processing sessions:  10%|▉         | 38/383 [01:08<11:59,  2.08s/session]
# Dataset 0 (DAWH):  78%|███████▊  | 38/49 [01:08<00:22,  2.08s/session, fitted=38]
# Processing sessions:  10%|█         | 39/383 [01:09<10:59,  1.92s/session]
# Dataset 0 (DAWH):  80%|███████▉  | 39/49 [01:09<00:19,  1.92s/session, fitted=39]
# Processing sessions:  10%|█         | 40/383 [01:10<09:43,  1.70s/session]
# Dataset 0 (DAWH):  82%|████████▏ | 40/49 [01:10<00:15,  1.70s/session, fitted=40]
# Processing sessions:  11%|█         | 41/383 [01:12<10:37,  1.86s/session]
# Dataset 0 (DAWH):  84%|████████▎ | 41/49 [01:13<00:14,  1.86s/session, fitted=41]
# Processing sessions:  11%|█         | 42/383 [01:14<09:56,  1.75s/session]
# Dataset 0 (DAWH):  86%|████████▌ | 42/49 [01:14<00:12,  1.75s/session, fitted=42]
# Processing sessions:  11%|█         | 43/383 [01:16<10:13,  1.81s/session]
# Dataset 0 (DAWH):  88%|████████▊ | 43/49 [01:16<00:10,  1.81s/session, fitted=43]
# Processing sessions:  11%|█▏        | 44/383 [01:17<09:11,  1.63s/session]
# Dataset 0 (DAWH):  90%|████████▉ | 44/49 [01:17<00:08,  1.63s/session, fitted=44]
# Processing sessions:  12%|█▏        | 45/383 [01:18<08:28,  1.50s/session]
# Dataset 0 (DAWH):  92%|█████████▏| 45/49 [01:18<00:06,  1.50s/session, fitted=45]
# Processing sessions:  12%|█▏        | 46/383 [01:20<08:13,  1.46s/session]
# Dataset 0 (DAWH):  94%|█████████▍| 46/49 [01:20<00:04,  1.46s/session, fitted=46]
# Processing sessions:  12%|█▏        | 47/383 [01:21<07:43,  1.38s/session]
# Dataset 0 (DAWH):  96%|█████████▌| 47/49 [01:21<00:02,  1.38s/session, fitted=47]
# Processing sessions:  13%|█▎        | 48/383 [01:23<08:13,  1.47s/session]
# Dataset 0 (DAWH):  98%|█████████▊| 48/49 [01:23<00:01,  1.47s/session, fitted=48]
# Processing sessions:  13%|█▎        | 49/383 [01:24<08:21,  1.50s/session]
# Dataset 0 (DAWH): 100%|██████████| 49/49 [01:24<00:00,  1.50s/session, fitted=49]
#
# Dataset 1 (TAB):   0%|          | 0/32 [00:00<?, ?session/s]
# Processing sessions:  13%|█▎        | 50/383 [01:27<11:08,  2.01s/session]
# Dataset 1 (TAB):   3%|▎         | 1/32 [00:03<01:38,  3.18s/session, fitted=50]
# Processing sessions:  13%|█▎        | 51/383 [01:29<10:59,  1.99s/session]
# Dataset 1 (TAB):   6%|▋         | 2/32 [00:05<01:13,  2.45s/session, fitted=51]
# Processing sessions:  14%|█▎        | 52/383 [01:31<10:03,  1.82s/session]
# Dataset 1 (TAB):   9%|▉         | 3/32 [00:06<00:57,  1.99s/session, fitted=52]
# Processing sessions:  14%|█▍        | 53/383 [01:35<13:26,  2.44s/session]
# Dataset 1 (TAB):  12%|█▎        | 4/32 [00:10<01:16,  2.74s/session, fitted=53]
# Processing sessions:  14%|█▍        | 54/383 [01:35<10:39,  1.95s/session]
# Dataset 1 (TAB):  16%|█▌        | 5/32 [00:11<00:54,  2.03s/session, fitted=54]
# Processing sessions:  14%|█▍        | 55/383 [01:38<12:08,  2.22s/session]
# Dataset 1 (TAB):  19%|█▉        | 6/32 [00:14<01:00,  2.32s/session, fitted=55]
# Processing sessions:  15%|█▍        | 56/383 [01:41<12:24,  2.28s/session]
# Dataset 1 (TAB):  22%|██▏       | 7/32 [00:16<00:58,  2.35s/session, fitted=56]
# Processing sessions:  15%|█▍        | 57/383 [01:44<13:27,  2.48s/session]
# Dataset 1 (TAB):  25%|██▌       | 8/32 [00:19<01:00,  2.54s/session, fitted=57]
# Processing sessions:  15%|█▌        | 58/383 [01:46<13:15,  2.45s/session]
# Dataset 1 (TAB):  28%|██▊       | 9/32 [00:21<00:57,  2.49s/session, fitted=58]
# Processing sessions:  15%|█▌        | 59/383 [01:49<13:37,  2.52s/session]
# Dataset 1 (TAB):  31%|███▏      | 10/32 [00:24<00:56,  2.55s/session, fitted=59]
# Processing sessions:  16%|█▌        | 60/383 [01:51<13:26,  2.50s/session]
# Dataset 1 (TAB):  34%|███▍      | 11/32 [00:26<00:52,  2.52s/session, fitted=60]
# Processing sessions:  16%|█▌        | 61/383 [01:53<11:41,  2.18s/session]
# Dataset 1 (TAB):  38%|███▊      | 12/32 [00:28<00:43,  2.19s/session, fitted=61]
# Processing sessions:  16%|█▌        | 62/383 [01:54<10:31,  1.97s/session]
# Dataset 1 (TAB):  41%|████      | 13/32 [00:29<00:37,  1.97s/session, fitted=62]
# Processing sessions:  16%|█▋        | 63/383 [01:56<10:40,  2.00s/session]
# Dataset 1 (TAB):  44%|████▍     | 14/32 [00:31<00:36,  2.01s/session, fitted=63]
# Processing sessions:  17%|█▋        | 64/383 [01:58<10:23,  1.95s/session]
# Dataset 1 (TAB):  47%|████▋     | 15/32 [00:33<00:33,  1.96s/session, fitted=64]
# Processing sessions:  17%|█▋        | 65/383 [02:00<10:47,  2.03s/session]
# Dataset 1 (TAB):  50%|█████     | 16/32 [00:36<00:32,  2.04s/session, fitted=65]
# Processing sessions:  17%|█▋        | 66/383 [02:02<10:48,  2.05s/session]
# Dataset 1 (TAB):  53%|█████▎    | 17/32 [00:38<00:30,  2.05s/session, fitted=66]
# Processing sessions:  17%|█▋        | 67/383 [02:03<09:22,  1.78s/session]
# Dataset 1 (TAB):  56%|█████▋    | 18/32 [00:39<00:24,  1.78s/session, fitted=67]
# Processing sessions:  18%|█▊        | 68/383 [02:05<09:23,  1.79s/session]
# Dataset 1 (TAB):  59%|█████▉    | 19/32 [00:41<00:23,  1.79s/session, fitted=68]
# Processing sessions:  18%|█▊        | 69/383 [02:07<08:55,  1.71s/session]
# Dataset 1 (TAB):  62%|██████▎   | 20/32 [00:42<00:20,  1.71s/session, fitted=69]
# Processing sessions:  18%|█▊        | 70/383 [02:08<08:39,  1.66s/session]
# Dataset 1 (TAB):  66%|██████▌   | 21/32 [00:44<00:18,  1.66s/session, fitted=70]
# Processing sessions:  19%|█▊        | 71/383 [02:10<08:13,  1.58s/session]
# Dataset 1 (TAB):  69%|██████▉   | 22/32 [00:45<00:15,  1.58s/session, fitted=71]
# Processing sessions:  19%|█▉        | 72/383 [02:11<08:03,  1.55s/session]
# Dataset 1 (TAB):  72%|███████▏  | 23/32 [00:47<00:13,  1.55s/session, fitted=72]
# Processing sessions:  19%|█▉        | 73/383 [02:13<08:57,  1.73s/session]
# Dataset 1 (TAB):  75%|███████▌  | 24/32 [00:49<00:13,  1.73s/session, fitted=73]
# Processing sessions:  19%|█▉        | 74/383 [02:15<09:24,  1.83s/session]
# Dataset 1 (TAB):  78%|███████▊  | 25/32 [00:51<00:12,  1.83s/session, fitted=74]
# Processing sessions:  20%|█▉        | 75/383 [02:17<09:28,  1.84s/session]
# Dataset 1 (TAB):  81%|████████▏ | 26/32 [00:53<00:11,  1.84s/session, fitted=75]
# Processing sessions:  20%|█▉        | 76/383 [02:19<09:40,  1.89s/session]
# Dataset 1 (TAB):  84%|████████▍ | 27/32 [00:55<00:09,  1.89s/session, fitted=76]
# Processing sessions:  20%|██        | 77/383 [02:21<09:13,  1.81s/session]
# Dataset 1 (TAB):  88%|████████▊ | 28/32 [00:56<00:07,  1.81s/session, fitted=77]
# Processing sessions:  20%|██        | 78/383 [02:23<09:26,  1.86s/session]
# Dataset 1 (TAB):  91%|█████████ | 29/32 [00:58<00:05,  1.86s/session, fitted=78]
# Processing sessions:  21%|██        | 79/383 [02:25<10:23,  2.05s/session]
# Dataset 1 (TAB):  94%|█████████▍| 30/32 [01:01<00:04,  2.05s/session, fitted=79]
# Processing sessions:  21%|██        | 80/383 [02:28<11:33,  2.29s/session]
# Dataset 1 (TAB):  97%|█████████▋| 31/32 [01:04<00:02,  2.29s/session, fitted=80]
# Processing sessions:  21%|██        | 81/383 [02:29<09:37,  1.91s/session]
# Dataset 1 (TAB): 100%|██████████| 32/32 [01:05<00:00,  1.91s/session, fitted=81]
#
# Dataset 2 (TAB):   0%|          | 0/122 [00:00<?, ?session/s]
# Processing sessions:  21%|██▏       | 82/383 [02:31<08:47,  1.75s/session]
# Dataset 2 (TAB):   1%|          | 1/122 [00:01<02:46,  1.38s/session, fitted=82]
# Processing sessions:  22%|██▏       | 83/383 [02:32<08:31,  1.71s/session]
# Dataset 2 (TAB):   2%|▏         | 2/122 [00:02<03:00,  1.51s/session, fitted=83]
# Processing sessions:  22%|██▏       | 84/383 [02:34<08:36,  1.73s/session]
# Dataset 2 (TAB):   2%|▏         | 3/122 [00:04<03:13,  1.63s/session, fitted=84]
# Processing sessions:  22%|██▏       | 85/383 [02:35<07:31,  1.52s/session]
# Dataset 2 (TAB):   3%|▎         | 4/122 [00:05<02:43,  1.39s/session, fitted=85]
# Processing sessions:  22%|██▏       | 86/383 [02:36<07:18,  1.48s/session]
# Dataset 2 (TAB):   4%|▍         | 5/122 [00:07<02:42,  1.39s/session, fitted=86]
# Processing sessions:  23%|██▎       | 87/383 [02:39<08:32,  1.73s/session]
# Dataset 2 (TAB):   5%|▍         | 6/122 [00:09<03:18,  1.71s/session, fitted=87]
# Processing sessions:  23%|██▎       | 88/383 [02:40<07:53,  1.61s/session]
# Dataset 2 (TAB):   6%|▌         | 7/122 [00:10<03:01,  1.58s/session, fitted=88]
# Processing sessions:  23%|██▎       | 89/383 [02:43<09:22,  1.91s/session]
# Dataset 2 (TAB):   7%|▋         | 8/122 [00:13<03:38,  1.91s/session, fitted=89]
# Processing sessions:  23%|██▎       | 90/383 [02:45<10:35,  2.17s/session]
# Dataset 2 (TAB):   7%|▋         | 9/122 [00:16<04:06,  2.18s/session, fitted=90]
# Processing sessions:  24%|██▍       | 91/383 [02:48<11:06,  2.28s/session]
# Dataset 2 (TAB):   8%|▊         | 10/122 [00:18<04:16,  2.29s/session, fitted=91]
# Processing sessions:  24%|██▍       | 92/383 [02:49<09:34,  1.97s/session]
# Dataset 2 (TAB):   9%|▉         | 11/122 [00:19<03:39,  1.97s/session, fitted=92]
# Processing sessions:  24%|██▍       | 93/383 [02:52<10:53,  2.25s/session]
# Dataset 2 (TAB):  10%|▉         | 12/122 [00:22<04:08,  2.26s/session, fitted=93]
# Processing sessions:  25%|██▍       | 94/383 [02:55<11:07,  2.31s/session]
# Dataset 2 (TAB):  11%|█         | 13/122 [00:25<04:12,  2.32s/session, fitted=94]
# Processing sessions:  25%|██▍       | 95/383 [02:58<13:08,  2.74s/session]
# Dataset 2 (TAB):  11%|█▏        | 14/122 [00:29<04:56,  2.74s/session, fitted=95]
# Processing sessions:  25%|██▌       | 96/383 [03:02<14:15,  2.98s/session]
# Dataset 2 (TAB):  12%|█▏        | 15/122 [00:32<05:19,  2.99s/session, fitted=96]
# Processing sessions:  25%|██▌       | 97/383 [03:04<12:55,  2.71s/session]
# Dataset 2 (TAB):  13%|█▎        | 16/122 [00:34<04:47,  2.71s/session, fitted=97]
# Processing sessions:  26%|██▌       | 98/383 [03:07<13:59,  2.95s/session]
# Dataset 2 (TAB):  14%|█▍        | 17/122 [00:38<05:09,  2.95s/session, fitted=98]
# Processing sessions:  26%|██▌       | 99/383 [03:10<13:47,  2.91s/session]
# Dataset 2 (TAB):  15%|█▍        | 18/122 [00:41<05:03,  2.91s/session, fitted=99]
# Processing sessions:  26%|██▌       | 100/383 [03:13<13:11,  2.80s/session]
# Dataset 2 (TAB):  16%|█▌        | 19/122 [00:43<04:48,  2.80s/session, fitted=100]
# Processing sessions:  26%|██▋       | 101/383 [03:14<11:14,  2.39s/session]
# Dataset 2 (TAB):  16%|█▋        | 20/122 [00:45<04:03,  2.39s/session, fitted=101]
# Processing sessions:  27%|██▋       | 102/383 [03:16<10:05,  2.16s/session]
# Dataset 2 (TAB):  17%|█▋        | 21/122 [00:46<03:37,  2.16s/session, fitted=102]
# Processing sessions:  27%|██▋       | 103/383 [03:17<09:08,  1.96s/session]
# Dataset 2 (TAB):  18%|█▊        | 22/122 [00:48<03:15,  1.96s/session, fitted=103]
# Processing sessions:  27%|██▋       | 104/383 [03:18<07:49,  1.68s/session]
# Dataset 2 (TAB):  19%|█▉        | 23/122 [00:49<02:46,  1.68s/session, fitted=104]
# Processing sessions:  27%|██▋       | 105/383 [03:21<09:37,  2.08s/session]
# Dataset 2 (TAB):  20%|█▉        | 24/122 [00:52<03:23,  2.08s/session, fitted=105]
# Processing sessions:  28%|██▊       | 106/383 [03:24<09:54,  2.15s/session]
# Dataset 2 (TAB):  20%|██        | 25/122 [00:54<03:28,  2.15s/session, fitted=106]
# Processing sessions:  28%|██▊       | 107/383 [03:25<09:21,  2.03s/session]
# Dataset 2 (TAB):  21%|██▏       | 26/122 [00:56<03:15,  2.03s/session, fitted=107]
# Processing sessions:  28%|██▊       | 108/383 [03:27<08:37,  1.88s/session]
# Dataset 2 (TAB):  22%|██▏       | 27/122 [00:57<02:58,  1.88s/session, fitted=108]
# Processing sessions:  28%|██▊       | 109/383 [03:29<08:52,  1.94s/session]
# Dataset 2 (TAB):  23%|██▎       | 28/122 [00:59<03:02,  1.94s/session, fitted=109]
# Processing sessions:  29%|██▊       | 110/383 [03:31<09:00,  1.98s/session]
# Dataset 2 (TAB):  24%|██▍       | 29/122 [01:01<03:04,  1.98s/session, fitted=110]
# Processing sessions:  29%|██▉       | 111/383 [03:34<09:34,  2.11s/session]
# Dataset 2 (TAB):  25%|██▍       | 30/122 [01:04<03:14,  2.11s/session, fitted=111]
# Processing sessions:  29%|██▉       | 112/383 [03:35<09:13,  2.04s/session]
# Dataset 2 (TAB):  25%|██▌       | 31/122 [01:06<03:05,  2.04s/session, fitted=112]
# Processing sessions:  30%|██▉       | 113/383 [03:38<10:16,  2.28s/session]
# Dataset 2 (TAB):  26%|██▌       | 32/122 [01:09<03:25,  2.28s/session, fitted=113]
# Processing sessions:  30%|██▉       | 114/383 [03:40<09:17,  2.07s/session]
# Dataset 2 (TAB):  27%|██▋       | 33/122 [01:10<03:04,  2.07s/session, fitted=114]
# Processing sessions:  30%|███       | 115/383 [03:41<07:38,  1.71s/session]
# Dataset 2 (TAB):  28%|██▊       | 34/122 [01:11<02:30,  1.71s/session, fitted=115]
# Processing sessions:  30%|███       | 116/383 [03:42<07:15,  1.63s/session]
# Dataset 2 (TAB):  29%|██▊       | 35/122 [01:12<02:21,  1.63s/session, fitted=116]
# Processing sessions:  31%|███       | 117/383 [03:44<07:57,  1.79s/session]
# Dataset 2 (TAB):  30%|██▉       | 36/122 [01:15<02:34,  1.79s/session, fitted=117]
# Processing sessions:  31%|███       | 118/383 [03:48<10:05,  2.29s/session]
# Dataset 2 (TAB):  30%|███       | 37/122 [01:18<03:14,  2.29s/session, fitted=118]
# Processing sessions:  31%|███       | 119/383 [03:50<09:46,  2.22s/session]
# Dataset 2 (TAB):  31%|███       | 38/122 [01:20<03:06,  2.22s/session, fitted=119]
# Processing sessions:  31%|███▏      | 120/383 [03:51<08:55,  2.04s/session]
# Dataset 2 (TAB):  32%|███▏      | 39/122 [01:22<02:49,  2.04s/session, fitted=120]
# Processing sessions:  32%|███▏      | 121/383 [03:53<08:05,  1.85s/session]
# Dataset 2 (TAB):  33%|███▎      | 40/122 [01:23<02:32,  1.85s/session, fitted=121]
# Processing sessions:  32%|███▏      | 122/383 [03:56<09:59,  2.30s/session]
# Dataset 2 (TAB):  34%|███▎      | 41/122 [01:26<03:06,  2.30s/session, fitted=122]
# Processing sessions:  32%|███▏      | 123/383 [03:58<09:47,  2.26s/session]
# Dataset 2 (TAB):  34%|███▍      | 42/122 [01:29<03:00,  2.26s/session, fitted=123]
# Processing sessions:  32%|███▏      | 124/383 [04:01<10:24,  2.41s/session]
# Dataset 2 (TAB):  35%|███▌      | 43/122 [01:31<03:10,  2.41s/session, fitted=124]
# Processing sessions:  33%|███▎      | 125/383 [04:04<11:27,  2.67s/session]
# Dataset 2 (TAB):  36%|███▌      | 44/122 [01:35<03:27,  2.67s/session, fitted=125]
# Processing sessions:  33%|███▎      | 126/383 [04:06<10:24,  2.43s/session]
# Dataset 2 (TAB):  37%|███▋      | 45/122 [01:37<03:07,  2.43s/session, fitted=126]
# Processing sessions:  33%|███▎      | 127/383 [04:08<09:16,  2.17s/session]
# Dataset 2 (TAB):  38%|███▊      | 46/122 [01:38<02:45,  2.17s/session, fitted=127]
# Processing sessions:  33%|███▎      | 128/383 [04:10<09:12,  2.17s/session]
# Dataset 2 (TAB):  39%|███▊      | 47/122 [01:40<02:42,  2.17s/session, fitted=128]
# Processing sessions:  34%|███▎      | 129/383 [04:12<08:42,  2.06s/session]
# Dataset 2 (TAB):  39%|███▉      | 48/122 [01:42<02:32,  2.06s/session, fitted=129]
# Processing sessions:  34%|███▍      | 130/383 [04:13<07:50,  1.86s/session]
# Dataset 2 (TAB):  40%|████      | 49/122 [01:43<02:15,  1.86s/session, fitted=130]
# Processing sessions:  34%|███▍      | 131/383 [04:16<09:16,  2.21s/session]
# Dataset 2 (TAB):  41%|████      | 50/122 [01:47<02:38,  2.21s/session, fitted=131]
# Processing sessions:  34%|███▍      | 132/383 [04:18<08:55,  2.13s/session]
# Dataset 2 (TAB):  42%|████▏     | 51/122 [01:48<02:31,  2.13s/session, fitted=132]
# Processing sessions:  35%|███▍      | 133/383 [04:22<11:12,  2.69s/session]
# Dataset 2 (TAB):  43%|████▎     | 52/122 [01:52<03:08,  2.69s/session, fitted=133]
# Processing sessions:  35%|███▍      | 134/383 [04:25<10:47,  2.60s/session]
# Dataset 2 (TAB):  43%|████▎     | 53/122 [01:55<02:59,  2.60s/session, fitted=134]
# Processing sessions:  35%|███▌      | 135/383 [04:27<10:16,  2.48s/session]
# Dataset 2 (TAB):  44%|████▍     | 54/122 [01:57<02:48,  2.48s/session, fitted=135]
# Processing sessions:  36%|███▌      | 136/383 [04:28<08:34,  2.08s/session]
# Dataset 2 (TAB):  45%|████▌     | 55/122 [01:58<02:19,  2.08s/session, fitted=136]
# Processing sessions:  36%|███▌      | 137/383 [04:29<07:34,  1.85s/session]
# Dataset 2 (TAB):  46%|████▌     | 56/122 [02:00<02:02,  1.85s/session, fitted=137]
# Processing sessions:  36%|███▌      | 138/383 [04:31<07:31,  1.84s/session]
# Dataset 2 (TAB):  47%|████▋     | 57/122 [02:01<01:59,  1.84s/session, fitted=138]
# Processing sessions:  36%|███▋      | 139/383 [04:33<07:55,  1.95s/session]
# Dataset 2 (TAB):  48%|████▊     | 58/122 [02:04<02:04,  1.95s/session, fitted=139]
# Processing sessions:  37%|███▋      | 140/383 [04:35<07:41,  1.90s/session]
# Dataset 2 (TAB):  48%|████▊     | 59/122 [02:05<01:59,  1.90s/session, fitted=140]
# Processing sessions:  37%|███▋      | 141/383 [04:38<08:59,  2.23s/session]
# Dataset 2 (TAB):  49%|████▉     | 60/122 [02:08<02:18,  2.23s/session, fitted=141]
# Processing sessions:  37%|███▋      | 142/383 [04:40<08:12,  2.04s/session]
# Dataset 2 (TAB):  50%|█████     | 61/122 [02:10<02:04,  2.04s/session, fitted=142]
# Processing sessions:  37%|███▋      | 143/383 [04:41<07:33,  1.89s/session]
# Dataset 2 (TAB):  51%|█████     | 62/122 [02:11<01:53,  1.89s/session, fitted=143]
# Processing sessions:  38%|███▊      | 144/383 [04:44<08:01,  2.01s/session]
# Dataset 2 (TAB):  52%|█████▏    | 63/122 [02:14<01:58,  2.01s/session, fitted=144]
# Processing sessions:  38%|███▊      | 145/383 [04:46<08:58,  2.26s/session]
# Dataset 2 (TAB):  52%|█████▏    | 64/122 [02:17<02:11,  2.26s/session, fitted=145]
# Processing sessions:  38%|███▊      | 146/383 [04:48<08:36,  2.18s/session]
# Dataset 2 (TAB):  53%|█████▎    | 65/122 [02:19<02:04,  2.18s/session, fitted=146]
# Processing sessions:  38%|███▊      | 147/383 [04:51<09:32,  2.42s/session]
# Dataset 2 (TAB):  54%|█████▍    | 66/122 [02:22<02:15,  2.42s/session, fitted=147]
# Processing sessions:  39%|███▊      | 148/383 [04:54<09:57,  2.54s/session]
# Dataset 2 (TAB):  55%|█████▍    | 67/122 [02:24<02:19,  2.54s/session, fitted=148]
# Processing sessions:  39%|███▉      | 149/383 [04:56<09:07,  2.34s/session]
# Dataset 2 (TAB):  56%|█████▌    | 68/122 [02:26<02:06,  2.34s/session, fitted=149]
# Processing sessions:  39%|███▉      | 150/383 [04:58<08:17,  2.13s/session]
# Dataset 2 (TAB):  57%|█████▋    | 69/122 [02:28<01:53,  2.13s/session, fitted=150]
# Processing sessions:  39%|███▉      | 151/383 [05:00<08:11,  2.12s/session]
# Dataset 2 (TAB):  57%|█████▋    | 70/122 [02:30<01:50,  2.12s/session, fitted=151]
# Processing sessions:  40%|███▉      | 152/383 [05:02<08:08,  2.11s/session]
# Dataset 2 (TAB):  58%|█████▊    | 71/122 [02:32<01:47,  2.11s/session, fitted=152]
# Processing sessions:  40%|███▉      | 153/383 [05:05<08:56,  2.33s/session]
# Dataset 2 (TAB):  59%|█████▉    | 72/122 [02:35<01:56,  2.33s/session, fitted=153]
# Processing sessions:  40%|████      | 154/383 [05:06<08:15,  2.17s/session]
# Dataset 2 (TAB):  60%|█████▉    | 73/122 [02:37<01:46,  2.17s/session, fitted=154]
# Processing sessions:  40%|████      | 155/383 [05:10<09:29,  2.50s/session]
# Dataset 2 (TAB):  61%|██████    | 74/122 [02:40<01:59,  2.50s/session, fitted=155]
# Processing sessions:  41%|████      | 156/383 [05:13<10:44,  2.84s/session]
# Dataset 2 (TAB):  61%|██████▏   | 75/122 [02:44<02:13,  2.84s/session, fitted=156]
# Processing sessions:  41%|████      | 157/383 [05:15<08:45,  2.33s/session]
# Dataset 2 (TAB):  62%|██████▏   | 76/122 [02:45<01:46,  2.33s/session, fitted=157]
# Processing sessions:  41%|████▏     | 158/383 [05:16<07:38,  2.04s/session]
# Dataset 2 (TAB):  63%|██████▎   | 77/122 [02:46<01:31,  2.04s/session, fitted=158]
# Processing sessions:  42%|████▏     | 159/383 [05:18<08:11,  2.19s/session]
# Dataset 2 (TAB):  64%|██████▍   | 78/122 [02:49<01:36,  2.19s/session, fitted=159]
# Processing sessions:  42%|████▏     | 160/383 [05:21<09:04,  2.44s/session]
# Dataset 2 (TAB):  65%|██████▍   | 79/122 [02:52<01:44,  2.44s/session, fitted=160]
# Processing sessions:  42%|████▏     | 161/383 [05:25<10:19,  2.79s/session]
# Dataset 2 (TAB):  66%|██████▌   | 80/122 [02:55<01:57,  2.79s/session, fitted=161]
# Processing sessions:  42%|████▏     | 162/383 [05:27<09:48,  2.66s/session]
# Dataset 2 (TAB):  66%|██████▋   | 81/122 [02:58<01:49,  2.66s/session, fitted=162]
# Processing sessions:  43%|████▎     | 163/383 [05:30<10:01,  2.73s/session]
# Dataset 2 (TAB):  67%|██████▋   | 82/122 [03:01<01:49,  2.73s/session, fitted=163]
# Processing sessions:  43%|████▎     | 164/383 [05:34<10:44,  2.94s/session]
# Dataset 2 (TAB):  68%|██████▊   | 83/122 [03:04<01:54,  2.94s/session, fitted=164]
# Processing sessions:  43%|████▎     | 165/383 [05:36<09:55,  2.73s/session]
# Dataset 2 (TAB):  69%|██████▉   | 84/122 [03:06<01:43,  2.73s/session, fitted=165]
# Processing sessions:  43%|████▎     | 166/383 [05:39<10:00,  2.77s/session]
# Dataset 2 (TAB):  70%|██████▉   | 85/122 [03:09<01:42,  2.77s/session, fitted=166]
# Processing sessions:  44%|████▎     | 167/383 [05:41<09:39,  2.68s/session]
# Dataset 2 (TAB):  70%|███████   | 86/122 [03:12<01:36,  2.68s/session, fitted=167]
# Processing sessions:  44%|████▍     | 168/383 [05:43<08:52,  2.47s/session]
# Dataset 2 (TAB):  71%|███████▏  | 87/122 [03:14<01:26,  2.47s/session, fitted=168]
# Processing sessions:  44%|████▍     | 169/383 [05:45<08:27,  2.37s/session]
# Dataset 2 (TAB):  72%|███████▏  | 88/122 [03:16<01:20,  2.37s/session, fitted=169]
# Processing sessions:  44%|████▍     | 170/383 [05:47<07:21,  2.07s/session]
# Dataset 2 (TAB):  73%|███████▎  | 89/122 [03:17<01:08,  2.07s/session, fitted=170]
# Processing sessions:  45%|████▍     | 171/383 [05:48<06:53,  1.95s/session]
# Dataset 2 (TAB):  74%|███████▍  | 90/122 [03:19<01:02,  1.95s/session, fitted=171]
# Processing sessions:  45%|████▍     | 172/383 [05:51<07:15,  2.06s/session]
# Dataset 2 (TAB):  75%|███████▍  | 91/122 [03:21<01:04,  2.06s/session, fitted=172]
# Processing sessions:  45%|████▌     | 173/383 [05:52<06:41,  1.91s/session]
# Dataset 2 (TAB):  75%|███████▌  | 92/122 [03:23<00:57,  1.91s/session, fitted=173]
# Processing sessions:  45%|████▌     | 174/383 [05:54<06:00,  1.72s/session]
# Dataset 2 (TAB):  76%|███████▌  | 93/122 [03:24<00:49,  1.72s/session, fitted=174]
# Processing sessions:  46%|████▌     | 175/383 [05:56<06:06,  1.76s/session]
# Dataset 2 (TAB):  77%|███████▋  | 94/122 [03:26<00:49,  1.76s/session, fitted=175]
# Processing sessions:  46%|████▌     | 176/383 [05:58<07:02,  2.04s/session]
# Dataset 2 (TAB):  78%|███████▊  | 95/122 [03:28<00:55,  2.04s/session, fitted=176]
# Processing sessions:  46%|████▌     | 177/383 [06:00<06:46,  1.97s/session]
# Dataset 2 (TAB):  79%|███████▊  | 96/122 [03:30<00:51,  1.97s/session, fitted=177]
# Processing sessions:  46%|████▋     | 178/383 [06:03<07:52,  2.30s/session]
# Dataset 2 (TAB):  80%|███████▉  | 97/122 [03:33<00:57,  2.30s/session, fitted=178]
# Processing sessions:  47%|████▋     | 179/383 [06:07<09:04,  2.67s/session]
# Dataset 2 (TAB):  80%|████████  | 98/122 [03:37<01:04,  2.67s/session, fitted=179]
# Processing sessions:  47%|████▋     | 180/383 [06:09<08:58,  2.65s/session]
# Dataset 2 (TAB):  81%|████████  | 99/122 [03:39<01:01,  2.65s/session, fitted=180]
# Processing sessions:  47%|████▋     | 181/383 [06:12<09:30,  2.83s/session]
# Dataset 2 (TAB):  82%|████████▏ | 100/122 [03:43<01:02,  2.83s/session, fitted=181]
# Processing sessions:  48%|████▊     | 182/383 [06:14<07:43,  2.30s/session]
# Dataset 2 (TAB):  83%|████████▎ | 101/122 [03:44<00:48,  2.30s/session, fitted=182]
# Processing sessions:  48%|████▊     | 183/383 [06:15<06:25,  1.93s/session]
# Dataset 2 (TAB):  84%|████████▎ | 102/122 [03:45<00:38,  1.93s/session, fitted=183]
# Processing sessions:  48%|████▊     | 184/383 [06:17<06:37,  2.00s/session]
# Dataset 2 (TAB):  84%|████████▍ | 103/122 [03:47<00:37,  2.00s/session, fitted=184]
# Processing sessions:  48%|████▊     | 185/383 [06:19<07:01,  2.13s/session]
# Dataset 2 (TAB):  85%|████████▌ | 104/122 [03:49<00:38,  2.13s/session, fitted=185]
# Processing sessions:  49%|████▊     | 186/383 [06:21<06:21,  1.94s/session]
# Dataset 2 (TAB):  86%|████████▌ | 105/122 [03:51<00:32,  1.94s/session, fitted=186]
# Processing sessions:  49%|████▉     | 187/383 [06:22<06:04,  1.86s/session]
# Dataset 2 (TAB):  87%|████████▋ | 106/122 [03:53<00:29,  1.86s/session, fitted=187]
# Processing sessions:  49%|████▉     | 188/383 [06:24<06:12,  1.91s/session]
# Dataset 2 (TAB):  88%|████████▊ | 107/122 [03:55<00:28,  1.91s/session, fitted=188]
# Processing sessions:  49%|████▉     | 189/383 [06:27<06:44,  2.08s/session]
# Dataset 2 (TAB):  89%|████████▊ | 108/122 [03:57<00:29,  2.08s/session, fitted=189]
# Processing sessions:  50%|████▉     | 190/383 [06:28<05:54,  1.84s/session]
# Dataset 2 (TAB):  89%|████████▉ | 109/122 [03:58<00:23,  1.84s/session, fitted=190]
# Processing sessions:  50%|████▉     | 191/383 [06:29<05:22,  1.68s/session]
# Dataset 2 (TAB):  90%|█████████ | 110/122 [04:00<00:20,  1.68s/session, fitted=191]
# Processing sessions:  50%|█████     | 192/383 [06:33<07:16,  2.29s/session]
# Dataset 2 (TAB):  91%|█████████ | 111/122 [04:03<00:25,  2.29s/session, fitted=192]
# Processing sessions:  50%|█████     | 193/383 [06:34<06:06,  1.93s/session]
# Dataset 2 (TAB):  92%|█████████▏| 112/122 [04:05<00:19,  1.93s/session, fitted=193]
# Processing sessions:  51%|█████     | 194/383 [06:36<06:08,  1.95s/session]
# Dataset 2 (TAB):  93%|█████████▎| 113/122 [04:07<00:17,  1.95s/session, fitted=194]
# Processing sessions:  51%|█████     | 195/383 [06:37<05:12,  1.66s/session]
# Dataset 2 (TAB):  93%|█████████▎| 114/122 [04:07<00:13,  1.66s/session, fitted=195]
# Processing sessions:  51%|█████     | 196/383 [06:41<07:32,  2.42s/session]
# Dataset 2 (TAB):  94%|█████████▍| 115/122 [04:12<00:16,  2.42s/session, fitted=196]
# Processing sessions:  51%|█████▏    | 197/383 [06:43<07:07,  2.30s/session]
# Dataset 2 (TAB):  95%|█████████▌| 116/122 [04:14<00:13,  2.30s/session, fitted=197]
# Processing sessions:  52%|█████▏    | 198/383 [06:45<06:09,  2.00s/session]
# Dataset 2 (TAB):  96%|█████████▌| 117/122 [04:15<00:09,  2.00s/session, fitted=198]
# Processing sessions:  52%|█████▏    | 199/383 [06:47<06:29,  2.12s/session]
# Dataset 2 (TAB):  97%|█████████▋| 118/122 [04:17<00:08,  2.12s/session, fitted=199]
# Processing sessions:  52%|█████▏    | 200/383 [06:52<08:37,  2.83s/session]
# Dataset 2 (TAB):  98%|█████████▊| 119/122 [04:22<00:08,  2.83s/session, fitted=200]
# Processing sessions:  52%|█████▏    | 201/383 [06:53<07:35,  2.50s/session]
# Dataset 2 (TAB):  98%|█████████▊| 120/122 [04:24<00:05,  2.50s/session, fitted=201]
# Processing sessions:  53%|█████▎    | 202/383 [06:57<08:20,  2.76s/session]
# Dataset 2 (TAB):  99%|█████████▉| 121/122 [04:27<00:02,  2.76s/session, fitted=202]
# Processing sessions:  53%|█████▎    | 203/383 [06:59<07:33,  2.52s/session]
# Dataset 2 (TAB): 100%|██████████| 122/122 [04:29<00:00,  2.52s/session, fitted=203]
#
# Dataset 3 (DAWH):   0%|          | 0/38 [00:00<?, ?session/s]
# Processing sessions:  53%|█████▎    | 204/383 [07:02<08:12,  2.75s/session]
# Dataset 3 (DAWH):   3%|▎         | 1/38 [00:03<02:01,  3.29s/session, fitted=204]
# Processing sessions:  54%|█████▎    | 205/383 [07:03<06:47,  2.29s/session]
# Dataset 3 (DAWH):   5%|▌         | 2/38 [00:04<01:14,  2.07s/session, fitted=205]
# Processing sessions:  54%|█████▍    | 206/383 [07:05<06:30,  2.21s/session]
# Dataset 3 (DAWH):   8%|▊         | 3/38 [00:06<01:11,  2.04s/session, fitted=206]
# Processing sessions:  54%|█████▍    | 207/383 [07:08<06:56,  2.37s/session]
# Dataset 3 (DAWH):  11%|█         | 4/38 [00:09<01:18,  2.32s/session, fitted=207]
# Processing sessions:  54%|█████▍    | 208/383 [07:09<06:10,  2.12s/session]
# Dataset 3 (DAWH):  13%|█▎        | 5/38 [00:10<01:07,  2.04s/session, fitted=208]
# Processing sessions:  55%|█████▍    | 209/383 [07:11<05:18,  1.83s/session]
# Dataset 3 (DAWH):  16%|█▌        | 6/38 [00:11<00:55,  1.74s/session, fitted=209]
# Processing sessions:  55%|█████▍    | 210/383 [07:12<05:15,  1.82s/session]
# Dataset 3 (DAWH):  18%|█▊        | 7/38 [00:13<00:54,  1.76s/session, fitted=210]
# Processing sessions:  55%|█████▌    | 211/383 [07:14<05:22,  1.88s/session]
# Dataset 3 (DAWH):  21%|██        | 8/38 [00:15<00:55,  1.84s/session, fitted=211]
# Processing sessions:  55%|█████▌    | 212/383 [07:16<05:26,  1.91s/session]
# Dataset 3 (DAWH):  24%|██▎       | 9/38 [00:17<00:54,  1.88s/session, fitted=212]
# Processing sessions:  56%|█████▌    | 213/383 [07:17<04:38,  1.64s/session]
# Dataset 3 (DAWH):  26%|██▋       | 10/38 [00:18<00:45,  1.61s/session, fitted=213]
# Processing sessions:  56%|█████▌    | 214/383 [07:19<04:47,  1.70s/session]
# Dataset 3 (DAWH):  29%|██▉       | 11/38 [00:20<00:45,  1.68s/session, fitted=214]
# Processing sessions:  56%|█████▌    | 215/383 [07:22<05:59,  2.14s/session]
# Dataset 3 (DAWH):  32%|███▏      | 12/38 [00:23<00:55,  2.13s/session, fitted=215]
# Processing sessions:  56%|█████▋    | 216/383 [07:24<05:51,  2.10s/session]
# Dataset 3 (DAWH):  34%|███▍      | 13/38 [00:25<00:52,  2.10s/session, fitted=216]
# Processing sessions:  57%|█████▋    | 217/383 [07:27<05:52,  2.12s/session]
# Dataset 3 (DAWH):  37%|███▋      | 14/38 [00:27<00:50,  2.12s/session, fitted=217]
# Processing sessions:  57%|█████▋    | 218/383 [07:27<04:27,  1.62s/session]
# Dataset 3 (DAWH):  39%|███▉      | 15/38 [00:28<00:37,  1.62s/session, fitted=218]
# Processing sessions:  57%|█████▋    | 219/383 [07:29<04:51,  1.78s/session]
# Dataset 3 (DAWH):  42%|████▏     | 16/38 [00:30<00:39,  1.78s/session, fitted=219]
# Processing sessions:  57%|█████▋    | 220/383 [07:32<05:45,  2.12s/session]
# Dataset 3 (DAWH):  45%|████▍     | 17/38 [00:33<00:44,  2.12s/session, fitted=220]
# Processing sessions:  58%|█████▊    | 221/383 [07:34<05:27,  2.02s/session]
# Dataset 3 (DAWH):  47%|████▋     | 18/38 [00:35<00:40,  2.02s/session, fitted=221]
# Processing sessions:  58%|█████▊    | 222/383 [07:36<05:18,  1.98s/session]
# Dataset 3 (DAWH):  50%|█████     | 19/38 [00:37<00:37,  1.98s/session, fitted=222]
# Processing sessions:  58%|█████▊    | 223/383 [07:38<05:29,  2.06s/session]
# Dataset 3 (DAWH):  53%|█████▎    | 20/38 [00:39<00:37,  2.06s/session, fitted=223]
# Processing sessions:  58%|█████▊    | 224/383 [07:40<05:09,  1.95s/session]
# Dataset 3 (DAWH):  55%|█████▌    | 21/38 [00:41<00:33,  1.95s/session, fitted=224]
# Processing sessions:  59%|█████▊    | 225/383 [07:41<04:21,  1.66s/session]
# Dataset 3 (DAWH):  58%|█████▊    | 22/38 [00:42<00:26,  1.65s/session, fitted=225]
# Processing sessions:  59%|█████▉    | 226/383 [07:44<05:16,  2.02s/session]
# Dataset 3 (DAWH):  61%|██████    | 23/38 [00:44<00:30,  2.02s/session, fitted=226]
# Processing sessions:  59%|█████▉    | 227/383 [07:44<04:19,  1.66s/session]
# Dataset 3 (DAWH):  63%|██████▎   | 24/38 [00:45<00:23,  1.66s/session, fitted=227]
# Processing sessions:  60%|█████▉    | 228/383 [07:46<04:23,  1.70s/session]
# Dataset 3 (DAWH):  66%|██████▌   | 25/38 [00:47<00:22,  1.70s/session, fitted=228]
# Processing sessions:  60%|█████▉    | 229/383 [07:48<04:29,  1.75s/session]
# Dataset 3 (DAWH):  68%|██████▊   | 26/38 [00:49<00:20,  1.75s/session, fitted=229]
# Processing sessions:  60%|██████    | 230/383 [07:50<04:35,  1.80s/session]
# Dataset 3 (DAWH):  71%|███████   | 27/38 [00:51<00:19,  1.80s/session, fitted=230]
# Processing sessions:  60%|██████    | 231/383 [07:51<04:00,  1.58s/session]
# Dataset 3 (DAWH):  74%|███████▎  | 28/38 [00:52<00:15,  1.58s/session, fitted=231]
# Processing sessions:  61%|██████    | 232/383 [07:53<03:57,  1.57s/session]
# Dataset 3 (DAWH):  76%|███████▋  | 29/38 [00:53<00:14,  1.57s/session, fitted=232]
# Processing sessions:  61%|██████    | 233/383 [07:54<03:47,  1.52s/session]
# Dataset 3 (DAWH):  79%|███████▉  | 30/38 [00:55<00:12,  1.52s/session, fitted=233]
# Processing sessions:  61%|██████    | 234/383 [07:55<03:41,  1.48s/session]
# Dataset 3 (DAWH):  82%|████████▏ | 31/38 [00:56<00:10,  1.48s/session, fitted=234]
# Processing sessions:  61%|██████▏   | 235/383 [07:56<03:17,  1.33s/session]
# Dataset 3 (DAWH):  84%|████████▍ | 32/38 [00:57<00:07,  1.33s/session, fitted=235]
# Processing sessions:  62%|██████▏   | 236/383 [07:58<03:39,  1.50s/session]
# Dataset 3 (DAWH):  87%|████████▋ | 33/38 [00:59<00:07,  1.50s/session, fitted=236]
# Processing sessions:  62%|██████▏   | 237/383 [08:00<03:41,  1.52s/session]
# Dataset 3 (DAWH):  89%|████████▉ | 34/38 [01:01<00:06,  1.52s/session, fitted=237]
# Processing sessions:  62%|██████▏   | 238/383 [08:01<03:41,  1.53s/session]
# Dataset 3 (DAWH):  92%|█████████▏| 35/38 [01:02<00:04,  1.53s/session, fitted=238]
# Processing sessions:  62%|██████▏   | 239/383 [08:03<03:39,  1.52s/session]
# Dataset 3 (DAWH):  95%|█████████▍| 36/38 [01:04<00:03,  1.52s/session, fitted=239]
# Processing sessions:  63%|██████▎   | 240/383 [08:04<03:23,  1.42s/session]
# Dataset 3 (DAWH):  97%|█████████▋| 37/38 [01:05<00:01,  1.42s/session, fitted=240]
# Processing sessions:  63%|██████▎   | 241/383 [08:05<03:18,  1.40s/session]
# Dataset 3 (DAWH): 100%|██████████| 38/38 [01:06<00:00,  1.40s/session, fitted=241]
#
# Dataset 4 (DAWH):   0%|          | 0/81 [00:00<?, ?session/s]
# Processing sessions:  63%|██████▎   | 242/383 [08:08<04:00,  1.70s/session]
# Dataset 4 (DAWH):   1%|          | 1/81 [00:02<03:12,  2.40s/session, fitted=242]
# Processing sessions:  63%|██████▎   | 243/383 [08:09<03:36,  1.55s/session]
# Dataset 4 (DAWH):   2%|▏         | 2/81 [00:03<02:12,  1.68s/session, fitted=243]
# Processing sessions:  64%|██████▎   | 244/383 [08:11<03:54,  1.69s/session]
# Dataset 4 (DAWH):   4%|▎         | 3/81 [00:05<02:23,  1.84s/session, fitted=244]
# Processing sessions:  64%|██████▍   | 245/383 [08:13<04:00,  1.74s/session]
# Dataset 4 (DAWH):   5%|▍         | 4/81 [00:07<02:22,  1.85s/session, fitted=245]
# Processing sessions:  64%|██████▍   | 246/383 [08:15<04:16,  1.87s/session]
# Dataset 4 (DAWH):   6%|▌         | 5/81 [00:09<02:29,  1.96s/session, fitted=246]
# Processing sessions:  64%|██████▍   | 247/383 [08:17<04:08,  1.82s/session]
# Dataset 4 (DAWH):   7%|▋         | 6/81 [00:11<02:21,  1.88s/session, fitted=247]
# Processing sessions:  65%|██████▍   | 248/383 [08:18<03:44,  1.66s/session]
# Dataset 4 (DAWH):   9%|▊         | 7/81 [00:12<02:04,  1.69s/session, fitted=248]
# Processing sessions:  65%|██████▌   | 249/383 [08:20<03:36,  1.62s/session]
# Dataset 4 (DAWH):  10%|▉         | 8/81 [00:14<01:59,  1.63s/session, fitted=249]
# Processing sessions:  65%|██████▌   | 250/383 [08:22<04:13,  1.91s/session]
# Dataset 4 (DAWH):  11%|█         | 9/81 [00:16<02:18,  1.93s/session, fitted=250]
# Processing sessions:  66%|██████▌   | 251/383 [08:24<04:06,  1.87s/session]
# Dataset 4 (DAWH):  12%|█▏        | 10/81 [00:18<02:13,  1.88s/session, fitted=251]
# Processing sessions:  66%|██████▌   | 252/383 [08:26<04:12,  1.93s/session]
# Dataset 4 (DAWH):  14%|█▎        | 11/81 [00:20<02:15,  1.94s/session, fitted=252]
# Processing sessions:  66%|██████▌   | 253/383 [08:28<04:13,  1.95s/session]
# Dataset 4 (DAWH):  15%|█▍        | 12/81 [00:22<02:14,  1.96s/session, fitted=253]
# Processing sessions:  66%|██████▋   | 254/383 [08:29<03:46,  1.76s/session]
# Dataset 4 (DAWH):  16%|█▌        | 13/81 [00:23<01:59,  1.76s/session, fitted=254]
# Processing sessions:  67%|██████▋   | 255/383 [08:30<03:11,  1.50s/session]
# Dataset 4 (DAWH):  17%|█▋        | 14/81 [00:24<01:40,  1.50s/session, fitted=255]
# Processing sessions:  67%|██████▋   | 256/383 [08:32<03:21,  1.59s/session]
# Dataset 4 (DAWH):  19%|█▊        | 15/81 [00:26<01:44,  1.59s/session, fitted=256]
# Processing sessions:  67%|██████▋   | 257/383 [08:34<03:23,  1.62s/session]
# Dataset 4 (DAWH):  20%|█▉        | 16/81 [00:28<01:45,  1.62s/session, fitted=257]
# Processing sessions:  67%|██████▋   | 258/383 [08:36<03:58,  1.91s/session]
# Dataset 4 (DAWH):  21%|██        | 17/81 [00:30<02:02,  1.91s/session, fitted=258]
# Processing sessions:  68%|██████▊   | 259/383 [08:38<03:47,  1.84s/session]
# Dataset 4 (DAWH):  22%|██▏       | 18/81 [00:32<01:55,  1.84s/session, fitted=259]
# Processing sessions:  68%|██████▊   | 260/383 [08:39<03:32,  1.73s/session]
# Dataset 4 (DAWH):  23%|██▎       | 19/81 [00:33<01:47,  1.73s/session, fitted=260]
# Processing sessions:  68%|██████▊   | 261/383 [08:41<03:35,  1.77s/session]
# Dataset 4 (DAWH):  25%|██▍       | 20/81 [00:35<01:47,  1.77s/session, fitted=261]
# Processing sessions:  68%|██████▊   | 262/383 [08:44<04:20,  2.15s/session]
# Dataset 4 (DAWH):  26%|██▌       | 21/81 [00:38<02:09,  2.15s/session, fitted=262]
# Processing sessions:  69%|██████▊   | 263/383 [08:46<03:54,  1.96s/session]
# Dataset 4 (DAWH):  27%|██▋       | 22/81 [00:40<01:55,  1.96s/session, fitted=263]
# Processing sessions:  69%|██████▉   | 264/383 [08:47<03:35,  1.81s/session]
# Dataset 4 (DAWH):  28%|██▊       | 23/81 [00:41<01:45,  1.81s/session, fitted=264]
# Processing sessions:  69%|██████▉   | 265/383 [08:49<03:19,  1.69s/session]
# Dataset 4 (DAWH):  30%|██▉       | 24/81 [00:43<01:36,  1.69s/session, fitted=265]
# Processing sessions:  69%|██████▉   | 266/383 [08:51<03:27,  1.77s/session]
# Dataset 4 (DAWH):  31%|███       | 25/81 [00:45<01:39,  1.77s/session, fitted=266]
# Processing sessions:  70%|██████▉   | 267/383 [08:51<02:45,  1.43s/session]
# Dataset 4 (DAWH):  32%|███▏      | 26/81 [00:45<01:18,  1.43s/session, fitted=267]
# Processing sessions:  70%|██████▉   | 268/383 [08:53<03:07,  1.63s/session]
# Dataset 4 (DAWH):  33%|███▎      | 27/81 [00:47<01:27,  1.63s/session, fitted=268]
# Processing sessions:  70%|███████   | 269/383 [08:56<03:54,  2.06s/session]
# Dataset 4 (DAWH):  35%|███▍      | 28/81 [00:51<01:49,  2.06s/session, fitted=269]
# Processing sessions:  70%|███████   | 270/383 [08:59<03:58,  2.11s/session]
# Dataset 4 (DAWH):  36%|███▌      | 29/81 [00:53<01:49,  2.11s/session, fitted=270]
# Processing sessions:  71%|███████   | 271/383 [09:02<04:47,  2.56s/session]
# Dataset 4 (DAWH):  37%|███▋      | 30/81 [00:56<02:10,  2.56s/session, fitted=271]
# Processing sessions:  71%|███████   | 272/383 [09:05<04:49,  2.61s/session]
# Dataset 4 (DAWH):  38%|███▊      | 31/81 [00:59<02:10,  2.61s/session, fitted=272]
# Processing sessions:  71%|███████▏  | 273/383 [09:06<03:45,  2.05s/session]
# Dataset 4 (DAWH):  40%|███▉      | 32/81 [01:00<01:40,  2.05s/session, fitted=273]
# Processing sessions:  72%|███████▏  | 274/383 [09:08<04:00,  2.20s/session]
# Dataset 4 (DAWH):  41%|████      | 33/81 [01:02<01:45,  2.20s/session, fitted=274]
# Processing sessions:  72%|███████▏  | 275/383 [09:09<03:23,  1.88s/session]
# Dataset 4 (DAWH):  42%|████▏     | 34/81 [01:04<01:28,  1.88s/session, fitted=275]
# Processing sessions:  72%|███████▏  | 276/383 [09:11<03:11,  1.79s/session]
# Dataset 4 (DAWH):  43%|████▎     | 35/81 [01:05<01:22,  1.79s/session, fitted=276]
# Processing sessions:  72%|███████▏  | 277/383 [09:12<02:38,  1.50s/session]
# Dataset 4 (DAWH):  44%|████▍     | 36/81 [01:06<01:07,  1.50s/session, fitted=277]
# Processing sessions:  73%|███████▎  | 278/383 [09:14<03:01,  1.73s/session]
# Dataset 4 (DAWH):  46%|████▌     | 37/81 [01:08<01:16,  1.73s/session, fitted=278]
# Processing sessions:  73%|███████▎  | 279/383 [09:16<03:16,  1.89s/session]
# Dataset 4 (DAWH):  47%|████▋     | 38/81 [01:10<01:21,  1.89s/session, fitted=279]
# Processing sessions:  73%|███████▎  | 280/383 [09:18<03:14,  1.88s/session]
# Dataset 4 (DAWH):  48%|████▊     | 39/81 [01:12<01:19,  1.88s/session, fitted=280]
# Processing sessions:  73%|███████▎  | 281/383 [09:20<03:14,  1.91s/session]
# Dataset 4 (DAWH):  49%|████▉     | 40/81 [01:14<01:18,  1.91s/session, fitted=281]
# Processing sessions:  74%|███████▎  | 282/383 [09:22<03:09,  1.87s/session]
# Dataset 4 (DAWH):  51%|█████     | 41/81 [01:16<01:14,  1.87s/session, fitted=282]
# Processing sessions:  74%|███████▍  | 283/383 [09:24<03:12,  1.92s/session]
# Dataset 4 (DAWH):  52%|█████▏    | 42/81 [01:18<01:14,  1.92s/session, fitted=283]
# Processing sessions:  74%|███████▍  | 284/383 [09:26<03:23,  2.05s/session]
# Dataset 4 (DAWH):  53%|█████▎    | 43/81 [01:20<01:17,  2.05s/session, fitted=284]
# Processing sessions:  74%|███████▍  | 285/383 [09:29<03:30,  2.15s/session]
# Dataset 4 (DAWH):  54%|█████▍    | 44/81 [01:23<01:19,  2.15s/session, fitted=285]
# Processing sessions:  75%|███████▍  | 286/383 [09:31<03:40,  2.27s/session]
# Dataset 4 (DAWH):  56%|█████▌    | 45/81 [01:25<01:21,  2.27s/session, fitted=286]
# Processing sessions:  75%|███████▍  | 287/383 [09:33<03:22,  2.11s/session]
# Dataset 4 (DAWH):  57%|█████▋    | 46/81 [01:27<01:13,  2.11s/session, fitted=287]
# Processing sessions:  75%|███████▌  | 288/383 [09:34<02:49,  1.78s/session]
# Dataset 4 (DAWH):  58%|█████▊    | 47/81 [01:28<01:00,  1.78s/session, fitted=288]
# Processing sessions:  75%|███████▌  | 289/383 [09:35<02:32,  1.62s/session]
# Dataset 4 (DAWH):  59%|█████▉    | 48/81 [01:29<00:53,  1.63s/session, fitted=289]
# Processing sessions:  76%|███████▌  | 290/383 [09:36<02:10,  1.40s/session]
# Dataset 4 (DAWH):  60%|██████    | 49/81 [01:30<00:44,  1.40s/session, fitted=290]
# Processing sessions:  76%|███████▌  | 291/383 [09:38<02:28,  1.61s/session]
# Dataset 4 (DAWH):  62%|██████▏   | 50/81 [01:32<00:50,  1.61s/session, fitted=291]
# Processing sessions:  76%|███████▌  | 292/383 [09:40<02:36,  1.72s/session]
# Dataset 4 (DAWH):  63%|██████▎   | 51/81 [01:34<00:51,  1.72s/session, fitted=292]
# Processing sessions:  77%|███████▋  | 293/383 [09:42<02:24,  1.61s/session]
# Dataset 4 (DAWH):  64%|██████▍   | 52/81 [01:36<00:46,  1.61s/session, fitted=293]
# Processing sessions:  77%|███████▋  | 294/383 [09:43<02:24,  1.63s/session]
# Dataset 4 (DAWH):  65%|██████▌   | 53/81 [01:37<00:45,  1.63s/session, fitted=294]
# Processing sessions:  77%|███████▋  | 295/383 [09:45<02:33,  1.75s/session]
# Dataset 4 (DAWH):  67%|██████▋   | 54/81 [01:39<00:47,  1.75s/session, fitted=295]
# Processing sessions:  77%|███████▋  | 296/383 [09:47<02:35,  1.78s/session]
# Dataset 4 (DAWH):  68%|██████▊   | 55/81 [01:41<00:46,  1.79s/session, fitted=296]
# Processing sessions:  78%|███████▊  | 297/383 [09:48<02:11,  1.53s/session]
# Dataset 4 (DAWH):  69%|██████▉   | 56/81 [01:42<00:38,  1.53s/session, fitted=297]
# Processing sessions:  78%|███████▊  | 298/383 [09:50<02:14,  1.58s/session]
# Dataset 4 (DAWH):  70%|███████   | 57/81 [01:44<00:37,  1.58s/session, fitted=298]
# Processing sessions:  78%|███████▊  | 299/383 [09:51<02:12,  1.58s/session]
# Dataset 4 (DAWH):  72%|███████▏  | 58/81 [01:45<00:36,  1.58s/session, fitted=299]
# Processing sessions:  78%|███████▊  | 300/383 [09:53<02:14,  1.61s/session]
# Dataset 4 (DAWH):  73%|███████▎  | 59/81 [01:47<00:35,  1.61s/session, fitted=300]
# Processing sessions:  79%|███████▊  | 301/383 [09:55<02:15,  1.66s/session]
# Dataset 4 (DAWH):  74%|███████▍  | 60/81 [01:49<00:34,  1.66s/session, fitted=301]
# Processing sessions:  79%|███████▉  | 302/383 [09:57<02:30,  1.86s/session]
# Dataset 4 (DAWH):  75%|███████▌  | 61/81 [01:51<00:37,  1.86s/session, fitted=302]
# Processing sessions:  79%|███████▉  | 303/383 [09:59<02:35,  1.94s/session]
# Dataset 4 (DAWH):  77%|███████▋  | 62/81 [01:53<00:36,  1.94s/session, fitted=303]
# Processing sessions:  79%|███████▉  | 304/383 [10:02<02:39,  2.02s/session]
# Dataset 4 (DAWH):  78%|███████▊  | 63/81 [01:56<00:36,  2.03s/session, fitted=304]
# Processing sessions:  80%|███████▉  | 305/383 [10:04<02:43,  2.10s/session]
# Dataset 4 (DAWH):  79%|███████▉  | 64/81 [01:58<00:35,  2.10s/session, fitted=305]
# Processing sessions:  80%|███████▉  | 306/383 [10:06<02:39,  2.08s/session]
# Dataset 4 (DAWH):  80%|████████  | 65/81 [02:00<00:33,  2.08s/session, fitted=306]
# Processing sessions:  80%|████████  | 307/383 [10:07<02:25,  1.91s/session]
# Dataset 4 (DAWH):  81%|████████▏ | 66/81 [02:01<00:28,  1.91s/session, fitted=307]
# Processing sessions:  80%|████████  | 308/383 [10:09<02:23,  1.91s/session]
# Dataset 4 (DAWH):  83%|████████▎ | 67/81 [02:03<00:26,  1.91s/session, fitted=308]
# Processing sessions:  81%|████████  | 309/383 [10:11<02:19,  1.89s/session]
# Dataset 4 (DAWH):  84%|████████▍ | 68/81 [02:05<00:24,  1.89s/session, fitted=309]
# Processing sessions:  81%|████████  | 310/383 [10:12<02:05,  1.73s/session]
# Dataset 4 (DAWH):  85%|████████▌ | 69/81 [02:07<00:20,  1.73s/session, fitted=310]
# Processing sessions:  81%|████████  | 311/383 [10:14<01:52,  1.57s/session]
# Dataset 4 (DAWH):  86%|████████▋ | 70/81 [02:08<00:17,  1.57s/session, fitted=311]
# Processing sessions:  81%|████████▏ | 312/383 [10:15<01:48,  1.52s/session]
# Dataset 4 (DAWH):  88%|████████▊ | 71/81 [02:09<00:15,  1.52s/session, fitted=312]
# Processing sessions:  82%|████████▏ | 313/383 [10:17<01:54,  1.64s/session]
# Dataset 4 (DAWH):  89%|████████▉ | 72/81 [02:11<00:14,  1.64s/session, fitted=313]
# Processing sessions:  82%|████████▏ | 314/383 [10:19<02:03,  1.79s/session]
# Dataset 4 (DAWH):  90%|█████████ | 73/81 [02:13<00:14,  1.79s/session, fitted=314]
# Processing sessions:  82%|████████▏ | 315/383 [10:21<02:06,  1.86s/session]
# Dataset 4 (DAWH):  91%|█████████▏| 74/81 [02:15<00:13,  1.86s/session, fitted=315]
# Processing sessions:  83%|████████▎ | 316/383 [10:23<01:58,  1.76s/session]
# Dataset 4 (DAWH):  93%|█████████▎| 75/81 [02:17<00:10,  1.76s/session, fitted=316]
# Processing sessions:  83%|████████▎ | 317/383 [10:26<02:33,  2.32s/session]
# Dataset 4 (DAWH):  94%|█████████▍| 76/81 [02:20<00:11,  2.32s/session, fitted=317]
# Processing sessions:  83%|████████▎ | 318/383 [10:27<02:01,  1.87s/session]
# Dataset 4 (DAWH):  95%|█████████▌| 77/81 [02:21<00:07,  1.87s/session, fitted=318]
# Processing sessions:  83%|████████▎ | 319/383 [10:29<01:56,  1.82s/session]
# Dataset 4 (DAWH):  96%|█████████▋| 78/81 [02:23<00:05,  1.82s/session, fitted=319]
# Processing sessions:  84%|████████▎ | 320/383 [10:30<01:48,  1.72s/session]
# Dataset 4 (DAWH):  98%|█████████▊| 79/81 [02:24<00:03,  1.72s/session, fitted=320]
# Processing sessions:  84%|████████▍ | 321/383 [10:32<01:44,  1.69s/session]
# Dataset 4 (DAWH):  99%|█████████▉| 80/81 [02:26<00:01,  1.69s/session, fitted=321]
# Processing sessions:  84%|████████▍ | 322/383 [10:33<01:24,  1.39s/session]
# Dataset 4 (DAWH): 100%|██████████| 81/81 [02:27<00:00,  1.39s/session, fitted=322]
#
# Dataset 5 (TAB):   0%|          | 0/61 [00:00<?, ?session/s]
# Processing sessions:  84%|████████▍ | 323/383 [10:34<01:27,  1.45s/session]
# Dataset 5 (TAB):   2%|▏         | 1/61 [00:01<01:36,  1.61s/session, fitted=323]
# Processing sessions:  85%|████████▍ | 324/383 [10:36<01:38,  1.66s/session]
# Dataset 5 (TAB):   3%|▎         | 2/61 [00:03<01:53,  1.93s/session, fitted=324]
# Processing sessions:  85%|████████▍ | 325/383 [10:37<01:25,  1.48s/session]
# Dataset 5 (TAB):   5%|▍         | 3/61 [00:04<01:28,  1.53s/session, fitted=325]
# Processing sessions:  85%|████████▌ | 326/383 [10:39<01:17,  1.36s/session]
# Dataset 5 (TAB):   7%|▋         | 4/61 [00:05<01:16,  1.35s/session, fitted=326]
# Processing sessions:  85%|████████▌ | 327/383 [10:40<01:25,  1.54s/session]
# Dataset 5 (TAB):   8%|▊         | 5/61 [00:07<01:27,  1.57s/session, fitted=327]
# Processing sessions:  86%|████████▌ | 328/383 [10:41<01:11,  1.29s/session]
# Dataset 5 (TAB):  10%|▉         | 6/61 [00:08<01:10,  1.28s/session, fitted=328]
# Processing sessions:  86%|████████▌ | 329/383 [10:43<01:14,  1.38s/session]
# Dataset 5 (TAB):  11%|█▏        | 7/61 [00:10<01:14,  1.38s/session, fitted=329]
# Processing sessions:  86%|████████▌ | 330/383 [10:44<01:14,  1.40s/session]
# Dataset 5 (TAB):  13%|█▎        | 8/61 [00:11<01:14,  1.40s/session, fitted=330]
# Processing sessions:  86%|████████▋ | 331/383 [10:46<01:17,  1.48s/session]
# Dataset 5 (TAB):  15%|█▍        | 9/61 [00:13<01:17,  1.49s/session, fitted=331]
# Processing sessions:  87%|████████▋ | 332/383 [10:47<01:16,  1.51s/session]
# Dataset 5 (TAB):  16%|█▋        | 10/61 [00:14<01:16,  1.51s/session, fitted=332]
# Processing sessions:  87%|████████▋ | 333/383 [10:49<01:15,  1.51s/session]
# Dataset 5 (TAB):  18%|█▊        | 11/61 [00:16<01:15,  1.51s/session, fitted=333]
# Processing sessions:  87%|████████▋ | 334/383 [10:51<01:20,  1.63s/session]
# Dataset 5 (TAB):  20%|█▉        | 12/61 [00:18<01:20,  1.64s/session, fitted=334]
# Processing sessions:  87%|████████▋ | 335/383 [10:52<01:04,  1.33s/session]
# Dataset 5 (TAB):  21%|██▏       | 13/61 [00:18<01:04,  1.33s/session, fitted=335]
# Processing sessions:  88%|████████▊ | 336/383 [10:53<01:07,  1.44s/session]
# Dataset 5 (TAB):  23%|██▎       | 14/61 [00:20<01:07,  1.44s/session, fitted=336]
# Processing sessions:  88%|████████▊ | 337/383 [10:54<01:03,  1.38s/session]
# Dataset 5 (TAB):  25%|██▍       | 15/61 [00:21<01:03,  1.37s/session, fitted=337]
# Processing sessions:  88%|████████▊ | 338/383 [10:57<01:13,  1.64s/session]
# Dataset 5 (TAB):  26%|██▌       | 16/61 [00:24<01:13,  1.64s/session, fitted=338]
# Processing sessions:  89%|████████▊ | 339/383 [11:01<01:42,  2.34s/session]
# Dataset 5 (TAB):  28%|██▊       | 17/61 [00:28<01:43,  2.34s/session, fitted=339]
# Processing sessions:  89%|████████▉ | 340/383 [11:02<01:24,  1.97s/session]
# Dataset 5 (TAB):  30%|██▉       | 18/61 [00:29<01:24,  1.97s/session, fitted=340]
# Processing sessions:  89%|████████▉ | 341/383 [11:03<01:11,  1.70s/session]
# Dataset 5 (TAB):  31%|███       | 19/61 [00:30<01:11,  1.70s/session, fitted=341]
# Processing sessions:  89%|████████▉ | 342/383 [11:04<01:03,  1.56s/session]
# Dataset 5 (TAB):  33%|███▎      | 20/61 [00:31<01:03,  1.56s/session, fitted=342]
# Processing sessions:  90%|████████▉ | 343/383 [11:06<01:04,  1.62s/session]
# Dataset 5 (TAB):  34%|███▍      | 21/61 [00:33<01:04,  1.62s/session, fitted=343]
# Processing sessions:  90%|████████▉ | 344/383 [11:07<00:56,  1.44s/session]
# Dataset 5 (TAB):  36%|███▌      | 22/61 [00:34<00:56,  1.44s/session, fitted=344]
# Processing sessions:  90%|█████████ | 345/383 [11:08<00:49,  1.31s/session]
# Dataset 5 (TAB):  38%|███▊      | 23/61 [00:35<00:49,  1.31s/session, fitted=345]
# Processing sessions:  90%|█████████ | 346/383 [11:10<00:52,  1.41s/session]
# Dataset 5 (TAB):  39%|███▉      | 24/61 [00:36<00:52,  1.41s/session, fitted=346]
# Processing sessions:  91%|█████████ | 347/383 [11:11<00:47,  1.32s/session]
# Dataset 5 (TAB):  41%|████      | 25/61 [00:37<00:47,  1.32s/session, fitted=347]
# Processing sessions:  91%|█████████ | 348/383 [11:13<01:02,  1.77s/session]
# Dataset 5 (TAB):  43%|████▎     | 26/61 [00:40<01:02,  1.77s/session, fitted=348]
# Processing sessions:  91%|█████████ | 349/383 [11:17<01:17,  2.28s/session]
# Dataset 5 (TAB):  44%|████▍     | 27/61 [00:44<01:17,  2.28s/session, fitted=349]
# Processing sessions:  91%|█████████▏| 350/383 [11:18<01:08,  2.07s/session]
# Dataset 5 (TAB):  46%|████▌     | 28/61 [00:45<01:08,  2.07s/session, fitted=350]
# Processing sessions:  92%|█████████▏| 351/383 [11:20<01:00,  1.88s/session]
# Dataset 5 (TAB):  48%|████▊     | 29/61 [00:47<01:00,  1.88s/session, fitted=351]
# Processing sessions:  92%|█████████▏| 352/383 [11:21<00:50,  1.63s/session]
# Dataset 5 (TAB):  49%|████▉     | 30/61 [00:48<00:50,  1.63s/session, fitted=352]
# Processing sessions:  92%|█████████▏| 353/383 [11:22<00:46,  1.54s/session]
# Dataset 5 (TAB):  51%|█████     | 31/61 [00:49<00:46,  1.54s/session, fitted=353]
# Processing sessions:  92%|█████████▏| 354/383 [11:23<00:39,  1.37s/session]
# Dataset 5 (TAB):  52%|█████▏    | 32/61 [00:50<00:39,  1.37s/session, fitted=354]
# Processing sessions:  93%|█████████▎| 355/383 [11:25<00:38,  1.37s/session]
# Dataset 5 (TAB):  54%|█████▍    | 33/61 [00:52<00:38,  1.37s/session, fitted=355]
# Processing sessions:  93%|█████████▎| 356/383 [11:26<00:37,  1.39s/session]
# Dataset 5 (TAB):  56%|█████▌    | 34/61 [00:53<00:37,  1.39s/session, fitted=356]
# Processing sessions:  93%|█████████▎| 357/383 [11:32<01:10,  2.72s/session]
# Dataset 5 (TAB):  57%|█████▋    | 35/61 [00:59<01:10,  2.72s/session, fitted=357]
# Processing sessions:  93%|█████████▎| 358/383 [11:34<01:02,  2.48s/session]
# Dataset 5 (TAB):  59%|█████▉    | 36/61 [01:01<01:02,  2.48s/session, fitted=358]
# Processing sessions:  94%|█████████▎| 359/383 [11:35<00:52,  2.20s/session]
# Dataset 5 (TAB):  61%|██████    | 37/61 [01:02<00:52,  2.20s/session, fitted=359]
# Processing sessions:  94%|█████████▍| 360/383 [11:38<00:50,  2.19s/session]
# Dataset 5 (TAB):  62%|██████▏   | 38/61 [01:04<00:50,  2.19s/session, fitted=360]
# Processing sessions:  94%|█████████▍| 361/383 [11:39<00:43,  1.99s/session]
# Dataset 5 (TAB):  64%|██████▍   | 39/61 [01:06<00:43,  1.99s/session, fitted=361]
# Processing sessions:  95%|█████████▍| 362/383 [11:42<00:47,  2.24s/session]
# Dataset 5 (TAB):  66%|██████▌   | 40/61 [01:09<00:47,  2.24s/session, fitted=362]
# Processing sessions:  95%|█████████▍| 363/383 [11:43<00:38,  1.92s/session]
# Dataset 5 (TAB):  67%|██████▋   | 41/61 [01:10<00:38,  1.92s/session, fitted=363]
# Processing sessions:  95%|█████████▌| 364/383 [11:45<00:37,  1.99s/session]
# Dataset 5 (TAB):  69%|██████▉   | 42/61 [01:12<00:37,  1.99s/session, fitted=364]
# Processing sessions:  95%|█████████▌| 365/383 [11:46<00:31,  1.73s/session]
# Dataset 5 (TAB):  70%|███████   | 43/61 [01:13<00:31,  1.73s/session, fitted=365]
# Processing sessions:  96%|█████████▌| 366/383 [11:48<00:30,  1.81s/session]
# Dataset 5 (TAB):  72%|███████▏  | 44/61 [01:15<00:30,  1.81s/session, fitted=366]
# Processing sessions:  96%|█████████▌| 367/383 [11:50<00:27,  1.74s/session]
# Dataset 5 (TAB):  74%|███████▍  | 45/61 [01:17<00:27,  1.74s/session, fitted=367]
# Processing sessions:  96%|█████████▌| 368/383 [11:52<00:26,  1.74s/session]
# Dataset 5 (TAB):  75%|███████▌  | 46/61 [01:19<00:26,  1.74s/session, fitted=368]
# Processing sessions:  96%|█████████▋| 369/383 [11:55<00:30,  2.15s/session]
# Dataset 5 (TAB):  77%|███████▋  | 47/61 [01:22<00:30,  2.15s/session, fitted=369]
# Processing sessions:  97%|█████████▋| 370/383 [11:57<00:28,  2.16s/session]
# Dataset 5 (TAB):  79%|███████▊  | 48/61 [01:24<00:28,  2.16s/session, fitted=370]
# Processing sessions:  97%|█████████▋| 371/383 [11:59<00:24,  2.07s/session]
# Dataset 5 (TAB):  80%|████████  | 49/61 [01:26<00:24,  2.07s/session, fitted=371]
# Processing sessions:  97%|█████████▋| 372/383 [12:00<00:20,  1.84s/session]
# Dataset 5 (TAB):  82%|████████▏ | 50/61 [01:27<00:20,  1.84s/session, fitted=372]
# Processing sessions:  97%|█████████▋| 373/383 [12:01<00:15,  1.58s/session]
# Dataset 5 (TAB):  84%|████████▎ | 51/61 [01:28<00:15,  1.58s/session, fitted=373]
# Processing sessions:  98%|█████████▊| 374/383 [12:02<00:12,  1.38s/session]
# Dataset 5 (TAB):  85%|████████▌ | 52/61 [01:29<00:12,  1.38s/session, fitted=374]
# Processing sessions:  98%|█████████▊| 375/383 [12:05<00:14,  1.78s/session]
# Dataset 5 (TAB):  87%|████████▋ | 53/61 [01:32<00:14,  1.78s/session, fitted=375]
# Processing sessions:  98%|█████████▊| 376/383 [12:06<00:12,  1.73s/session]
# Dataset 5 (TAB):  89%|████████▊ | 54/61 [01:33<00:12,  1.73s/session, fitted=376]
# Processing sessions:  98%|█████████▊| 377/383 [12:08<00:09,  1.61s/session]
# Dataset 5 (TAB):  90%|█████████ | 55/61 [01:35<00:09,  1.61s/session, fitted=377]
# Processing sessions:  99%|█████████▊| 378/383 [12:11<00:10,  2.17s/session]
# Dataset 5 (TAB):  92%|█████████▏| 56/61 [01:38<00:10,  2.17s/session, fitted=378]
# Processing sessions:  99%|█████████▉| 379/383 [12:12<00:07,  1.89s/session]
# Dataset 5 (TAB):  93%|█████████▎| 57/61 [01:39<00:07,  1.89s/session, fitted=379]
# Processing sessions:  99%|█████████▉| 380/383 [12:14<00:05,  1.80s/session]
# Dataset 5 (TAB):  95%|█████████▌| 58/61 [01:41<00:05,  1.80s/session, fitted=380]
# Processing sessions:  99%|█████████▉| 381/383 [12:15<00:03,  1.71s/session]
# Dataset 5 (TAB):  97%|█████████▋| 59/61 [01:42<00:03,  1.71s/session, fitted=381]
# Processing sessions: 100%|█████████▉| 382/383 [12:16<00:01,  1.45s/session]
# Dataset 5 (TAB):  98%|█████████▊| 60/61 [01:43<00:01,  1.45s/session, fitted=382]
# Processing sessions: 100%|██████████| 383/383 [12:18<00:00,  1.41s/session]
# Dataset 5 (TAB): 100%|██████████| 61/61 [01:44<00:00,  1.41s/session, fitted=383]
# Processing sessions: 100%|██████████| 383/383 [12:18<00:00,  1.93s/session]
# Parameter values by task:
#
# TAB task (n=215 sessions):
# RW Alpha: M=0.522, SD=0.238
# RW Beta:  M=4.506, SD=3.865
# SP Alpha: M=0.816, SD=0.205
# SP Beta:  M=3.594, SD=2.185
#
# DAWH task (n=168 sessions):
# RW Alpha: M=0.461, SD=0.285
# RW Beta:  M=3.090, SD=5.501
# SP Alpha: M=0.627, SD=0.238
# SP Beta:  M=2.370, SD=0.762
# Model comparison res:
#
# Contingency Table (AIC):
#               RW wins  SP wins
# TAB task:      165      50
# DAWH task:      43     125
#
# Chi-square test: chi^2 = 97.3797, p = 0.0000
#
# Saved results to: figs/parameter_fitting_results.csv

# %%
# Run length analysis
# model independent diagnostics

MAX_RUN = 5
STEADY_TRIALS = 20
BLOCK_LEN_TAB = 50
BLOCK_LEN_DAWH = 50
N_SIM = 20

# realdata results
def load_results_dataframe():
    if 'real_data_results' in globals():
        return globals()['real_data_results']


    csv_path = Path('figs/parameter_fitting_results.csv')

    if csv_path.exists():
        return pd.read_csv(csv_path)

    df = analyze_real_data()
    csv_path.parent.mkdir(exist_ok=True)
    df.to_csv(csv_path, index=False)

    return df



def compute_signed_run_predictor(choices, max_run=MAX_RUN):

    choices = np.asarray(choices, dtype=int)
    run_before = np.zeros(len(choices), dtype=int)
    prev_choice = None
    current_run = 0

    for t, choice in enumerate(choices):
        run_before[t] = np.clip(current_run, -max_run, max_run)
        if prev_choice is None or choice != prev_choice:
            current_run = 1 if choice == 1 else -1

        else:

            if choice == 0:
                current_run = current_run + 1 if current_run > 0 else 1
            else:
                current_run = current_run - 1 if current_run < 0 else -1

        prev_choice = choice

    return np.clip(run_before, -max_run, max_run)


#for steady state
def steady_state_mask(task, n_trials):\

    block_len = BLOCK_LEN_TAB if task == "TAB" else BLOCK_LEN_DAWH
    mask = np.zeros(n_trials, dtype=bool)

    for start in range(0, n_trials, block_len):
        end = min(start + block_len, n_trials)
        take_start = max(start, end - STEADY_TRIALS)
        mask[take_start:end] = True

    if not mask.any():
        mask[:] = True

    return mask


def accumulate(curve, choices, run_feat):

    for choice, run_val in zip(choices, run_feat):
        if run_val == 0:
            continue

        idx = run_val + MAX_RUN
        curve['counts'][idx] += 1

        if choice == 0:
            curve['left'][idx] += 1


# finalize the calc
def finalize(curve):

    counts = curve['counts']
    left = curve['left']

    probs = np.zeros_like(left, dtype=float)
    mask = counts > 0
    probs[mask] = left[mask] / counts[mask]
    probs[~mask] = np.nan


    return probs


# run length analysis
def analyze_run_length(real_data_results, data):

    run_values = np.arange(-MAX_RUN, MAX_RUN + 1)
    sources = {
        'real': {task: {'counts': np.zeros(len(run_values)), 'left': np.zeros(len(run_values))} for task in ['TAB', 'DAWH']},
        'rw': {task: {'counts': np.zeros(len(run_values)), 'left': np.zeros(len(run_values))} for task in ['TAB', 'DAWH']},
        'sp': {task: {'counts': np.zeros(len(run_values)), 'left': np.zeros(len(run_values))} for task in ['TAB', 'DAWH']},
    }


    for _, row in tqdm(real_data_results.iterrows(), total=len(real_data_results), desc="RunLength"):
        dataset_idx = int(row['dataset_idx'])
        session_idx = int(row['session_idx'])

        task = row['task']
        session = data[dataset_idx][session_idx]
        choices, _ = get_choices_rewards(session)

        n = len(choices)
        mask = steady_state_mask(task, n)
        run_feat = compute_signed_run_predictor(choices)
        accumulate(sources['real'][task], choices[mask], run_feat[mask])

        rw_alpha, rw_beta = row['rw_alpha'], row['rw_beta']
        sp_alpha, sp_beta = row['sp_alpha'], row['sp_beta']
        env_kwargs = {"block_len": BLOCK_LEN_TAB} if task == "TAB" else {"base": 0.02, "inc": 0.12, "max_p": 0.98}

        for _ in range(N_SIM):
            rw_choices, _ = simulate_RW(rw_alpha, rw_beta, n_trials=n, task=task, **env_kwargs)
            sp_choices, _ = simulate_SP(sp_alpha, sp_beta, n_trials=n, task=task, **env_kwargs)

            accumulate(sources['rw'][task], rw_choices[mask], compute_signed_run_predictor(rw_choices)[mask])
            accumulate(sources['sp'][task], sp_choices[mask], compute_signed_run_predictor(sp_choices)[mask])

    agg = {src: {task: finalize(sources[src][task]) for task in ['TAB', 'DAWH']} for src in sources}
    return run_values, agg

#plot the graphs
def plot_results(run_values, agg, fname='figs/run_length_analysis.png'):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
    for ax, task in zip(axes, ['TAB', 'DAWH']):

        ax.plot(run_values, agg['real'][task], label='Real data', linewidth=2)
        ax.plot(run_values, agg['rw'][task], label='RW sim', linestyle='--')
        ax.plot(run_values, agg['sp'][task], label='SP sim', linestyle=':')

        ax.set_xlabel('Signed run length')
        ax.set_ylabel('P(choose left)')
        ax.set_title(f'{task} task')
        ax.set_ylim(0, 1)

        ax.legend()
        ax.grid(alpha=0.3)

    plt.tight_layout()
    Path(fname).parent.mkdir(exist_ok=True)
    plt.savefig(fname, dpi=220, bbox_inches='tight')
    plt.show()


if __name__ == '__main__':
    real_data_results = load_results_dataframe()
    data = load_shin_data('shin_data.pkl')
    run_values, agg = analyze_run_length(real_data_results, data)
    plot_results(run_values, agg)
# Out:
#   Dataset 0: DAWH task, 49 sessions
#   Dataset 1: TAB task, 32 sessions
#   Dataset 2: TAB task, 122 sessions
#   Dataset 3: DAWH task, 38 sessions
#   Dataset 4: DAWH task, 81 sessions
#   Dataset 5: TAB task, 61 sessions
# RunLength: 100%|██████████| 383/383 [00:36<00:00, 10.41it/s]

# %%
# Delta Log Likelihood Analysis


#Analyze delta log likelihood distributions
def analyze_delta_loglikelihood(real_data_results):

    if real_data_results is None:
        return None

    df = real_data_results.copy()

    if 'delta_ll' not in df.columns:
        if 'rw_ll' in df.columns and 'sp_ll' in df.columns:
            df['delta_ll'] = df['sp_ll'] - df['rw_ll']

        else:
            return None

    tab_delta = df[df['task'] == 'TAB']['delta_ll'].values
    dawh_delta = df[df['task'] == 'DAWH']['delta_ll'].values

    # Stats tests
    if len(tab_delta) > 0 and len(dawh_delta) > 0:
        u_stat, p_mann = mannwhitneyu(tab_delta, dawh_delta, alternative='two-sided')
        t_stat, p_ttest = ttest_ind(tab_delta, dawh_delta)

    else:
        u_stat, p_mann, t_stat, p_ttest = 0, 1, 0, 1

    t_tab, p_tab = ttest_1samp(tab_delta, 0) if len(tab_delta) > 0 else (0, 1)
    t_dawh, p_dawh = ttest_1samp(dawh_delta, 0) if len(dawh_delta) > 0 else (0, 1)

    # effect size
    if len(tab_delta) > 0 and len(dawh_delta) > 0:

        pooled_std = np.sqrt(((len(tab_delta) - 1) * np.var(tab_delta) +
                              (len(dawh_delta) - 1) * np.var(dawh_delta)) /
                             (len(tab_delta) + len(dawh_delta) - 2))

        cohens_d = (np.mean(dawh_delta) - np.mean(tab_delta)) / pooled_std if pooled_std > 0 else 0

    else:
        cohens_d = 0

    # summary statistics
    summary_stats = {
        'Overall': {
            'n_sessions': len(df),
            'mean_delta_ll': df['delta_ll'].mean(),
            'median_delta_ll': df['delta_ll'].median(),
            'std_delta_ll': df['delta_ll'].std(),
            'n_SP_better': (df['delta_ll'] > 0).sum(),
            'pct_SP_better': (df['delta_ll'] > 0).mean() * 100,
            'n_RW_better': (df['delta_ll'] < 0).sum(),
            'pct_RW_better': (df['delta_ll'] < 0).mean() * 100,
        },
        'TAB': {
            'n_sessions': len(tab_delta),
            'mean_delta_ll': np.mean(tab_delta),
            'median_delta_ll': np.median(tab_delta),
            'std_delta_ll': np.std(tab_delta),
            'n_SP_better': (tab_delta > 0).sum(),
            'pct_SP_better': (tab_delta > 0).mean() * 100,
            'n_RW_better': (tab_delta < 0).sum(),
            'pct_RW_better': (tab_delta < 0).mean() * 100,
            't_test_vs_zero': t_tab,
            'p_test_vs_zero': p_tab,
        },
        'DAWH': {
            'n_sessions': len(dawh_delta),
            'mean_delta_ll': np.mean(dawh_delta),
            'median_delta_ll': np.median(dawh_delta),
            'std_delta_ll': np.std(dawh_delta),
            'n_SP_better': (dawh_delta > 0).sum(),
            'pct_SP_better': (dawh_delta > 0).mean() * 100,
            'n_RW_better': (dawh_delta < 0).sum(),
            'pct_RW_better': (dawh_delta < 0).mean() * 100,
            't_test_vs_zero': t_dawh,
            'p_test_vs_zero': p_dawh,
        },
        'Statistical_Tests': {
            'mannwhitney_p': p_mann,
            't_test_p': p_ttest,
            'cohens_d': cohens_d,
        }
    }

    summary_df = pd.DataFrame(summary_stats).T
    summary_path = "figs/delta_ll_summary_statistics.csv"
    summary_df.to_csv(summary_path)

    fig, axes = plt.subplots(1, 3, figsize=(15, 4))

    # histogram by task
    ax1 = axes[0]
    for task in ['TAB', 'DAWH']:

        task_df = df[df['task'] == task]

        if len(task_df) > 0:
            ax1.hist(task_df['delta_ll'], alpha=0.6, label=f'{task} (n={len(task_df)})',
                    bins=30, density=True)

    ax1.axvline(0, color='black', linestyle='--', linewidth=1)
    ax1.set_xlabel('ΔLogL (SP - RW)')
    ax1.set_ylabel('Density')
    ax1.set_title('Distribution of ΔLogL by Task')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Boxplot by task
    ax2 = axes[1]
    tab_delta_list = df[df['task'] == 'TAB']['delta_ll'].tolist()
    dawh_delta_list = df[df['task'] == 'DAWH']['delta_ll'].tolist()
    ax2.boxplot([tab_delta_list, dawh_delta_list], labels=['TAB', 'DAWH'])
    ax2.axhline(0, color='black', linestyle='--', linewidth=1)
    ax2.set_ylabel('ΔLogL (SP - RW)')
    ax2.set_title(f'ΔLogL by Task\n(Mann-Whitney p = {p_mann:.4f})')
    ax2.grid(True, alpha=0.3)

    # Cumulative distrib graph
    ax3 = axes[2]

    for task in ['TAB', 'DAWH']:
        task_df = df[df['task'] == task]

        if len(task_df) > 0:
            sorted_delta = np.sort(task_df['delta_ll'])
            y = np.arange(1, len(sorted_delta) + 1) / len(sorted_delta)
            ax3.plot(sorted_delta, y, label=f'{task}', linewidth=2)

    ax3.axvline(0, color='black', linestyle='--', linewidth=1, alpha=0.5)
    ax3.set_xlabel('ΔLogL (SP - RW)')
    ax3.set_ylabel('Cumulative Probability')
    ax3.set_title('Cumulative Distribution')

    ax3.legend()

    ax3.grid(True, alpha=0.3)

    plt.tight_layout()

    fname = "figs/delta_loglikelihood_analysis.png"
    plt.savefig(fname, dpi=220, bbox_inches="tight")

    plt.show()
    print(f"Saved: {fname}")

    print("\nDelta Log Likelihood Summary:")
    print(summary_df.round(4))

    return df, summary_df

# run
if 'real_data_results' in globals() and real_data_results is not None:
    result = analyze_delta_loglikelihood(real_data_results)
    if result is not None:
        delta_ll_results, delta_ll_summary = result
# Out:
# /tmp/ipython-input-3732139730.py:115: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax2.boxplot([tab_delta_list, dawh_delta_list], labels=['TAB', 'DAWH'])
# Saved: figs/delta_loglikelihood_analysis.png
#
# Delta Log Likelihood Summary:
#                    n_sessions  mean_delta_ll  median_delta_ll  std_delta_ll  \
# Overall                 383.0        -1.0382          -0.6795        7.7999
# TAB                     215.0        -4.8158          -4.1802        7.1732
# DAWH                    168.0         3.7961           3.5238        5.5545
# Statistical_Tests         NaN            NaN              NaN           NaN
#
#                    n_SP_better  pct_SP_better  n_RW_better  pct_RW_better  \
# Overall                  175.0        45.6919        208.0        54.3081
# TAB                       50.0        23.2558        165.0        76.7442
# DAWH                     125.0        74.4048         43.0        25.5952
# Statistical_Tests          NaN            NaN          NaN            NaN
#
#                    t_test_vs_zero  p_test_vs_zero  mannwhitney_p  t_test_p  \
# Overall                       NaN             NaN            NaN       NaN
# TAB                       -9.8211             0.0            NaN       NaN
# DAWH                       8.8318             0.0            NaN       NaN
# Statistical_Tests             NaN             NaN            0.0       0.0
#
#                    cohens_d
# Overall                 NaN
# TAB                     NaN
# DAWH                    NaN
# Statistical_Tests    1.3222

# %%
# Model Validation

# model independent behaviroal measures
def compute_behavioral_measures(choices, rewards):

    choices = np.array(choices)
    rewards = np.array(rewards)
    n_trials = len(choices)

    if n_trials == 0:
        return {}

    measures = {}

    measures['prop_right'] = np.mean(choices == 1)
    measures['prop_left'] = np.mean(choices == 0)

    # set zeros wsls
    if n_trials > 1:
        win_stay = 0
        win_shift = 0
        lose_stay = 0
        lose_shift = 0

        for t in range(1, n_trials):

            prev_choice = choices[t-1]
            prev_reward = rewards[t-1]
            curr_choice = choices[t]

            if prev_reward == 1:
                if curr_choice == prev_choice:
                    win_stay += 1
                else:
                    win_shift += 1
            else:
                if curr_choice == prev_choice:
                    lose_stay += 1
                else:
                    lose_shift += 1

        total_wins = win_stay + win_shift
        total_losses = lose_stay + lose_shift

        measures['win_stay_rate'] = win_stay / total_wins if total_wins > 0 else 0.0
        measures['lose_shift_rate'] = lose_shift / total_losses if total_losses > 0 else 0.0

    else:

        measures['win_stay_rate'] = 0.0
        measures['lose_shift_rate'] = 0.0

    measures['reward_rate'] = np.mean(rewards)

    if n_trials > 1:
        switches = np.sum(choices[1:] != choices[:-1])
        measures['switch_rate'] = switches / (n_trials - 1)

    else:
        measures['switch_rate'] = 0.0

    if n_trials > 0:
        run_lengths = []
        current_run = 1

        for t in range(1, n_trials):
            if choices[t] == choices[t-1]:
                current_run += 1
            else:
                run_lengths.append(current_run)
                current_run = 1

        run_lengths.append(current_run)
        measures['mean_run_length'] = np.mean(run_lengths) if len(run_lengths) > 0 else 1.0

    else:

        measures['mean_run_length'] = 1.0

    return measures


def estimate_side_reward_probs(choices, rewards):

    choices = np.asarray(choices)
    rewards = np.asarray(rewards)

    mask_L = choices == 0
    mask_R = choices == 1

    pL = rewards[mask_L].mean() if mask_L.any() else 0.5
    pR = rewards[mask_R].mean() if mask_R.any() else 0.5

    eps = 1e-3

    pL = float(np.clip(pL, eps, 1 - eps))
    pR = float(np.clip(pR, eps, 1 - eps))

    return pL, pR


def simulate_RW_stationary(alpha, beta, n_trials, pL, pR):

    A_L, A_R = 0.5, 0.5
    choices = np.zeros(n_trials, dtype=int)
    rewards = np.zeros(n_trials, dtype=int)

    for t in range(n_trials):
        p_right = softmax_prob(A_L, A_R, beta)
        a = RNG.binomial(1, p_right)
        choices[t] = a

        p = pR if a == 1 else pL
        r = RNG.binomial(1, p)
        rewards[t] = r

        if a == 0:
            A_L = (1.0 - alpha) * A_L + alpha * r
        else:
            A_R = (1.0 - alpha) * A_R + alpha * r

    return choices, rewards


def simulate_SP_stationary(alpha, beta, n_trials, pL, pR):

    A_L, A_R = 0.5, 0.5
    run_length_L = 0
    run_length_R = 0

    choices = np.zeros(n_trials, dtype=int)
    rewards = np.zeros(n_trials, dtype=int)

    # stack parameters based on run length of the *other* action
    for t in range(n_trials):

        X_L = compute_stack_parameter(A_L, run_length_R)
        X_R = compute_stack_parameter(A_R, run_length_L)

        S_L = A_L * X_L
        S_R = A_R * X_R

        p_right = softmax_prob(S_L, S_R, beta)
        a = RNG.binomial(1, p_right)
        choices[t] = a

        p = pR if a == 1 else pL
        r = RNG.binomial(1, p)
        rewards[t] = r

        if a == 0:
            A_L = (1.0 - alpha) * A_L + alpha * r
            run_length_L += 1
            run_length_R = 0
        else:
            A_R = (1.0 - alpha) * A_R + alpha * r
            run_length_R += 1
            run_length_L = 0

    return choices, rewards



#validate models by real data comp
def model_validation(real_data_results, pkl_path="shin_data.pkl", n_simulations=10):

    if real_data_results is None:
        return None

    data = load_shin_data(pkl_path)

    if data is None:
        return None

    validation_results = []



    pbar = tqdm(real_data_results.iterrows(), total=len(real_data_results),
                desc="Validating models", unit="session")

    for idx, row in pbar:

        dataset_idx = int(row['dataset_idx'])
        session_idx = int(row['session_idx'])

        task = row['task']
        winner_AIC = row['winner_AIC']

        choices_real, rewards_real, _ = extract_session_data(data, dataset_idx, session_idx)


        if choices_real is None:
            continue

        choices_real = np.array(choices_real)
        rewards_real = np.array(rewards_real)


        pL_hat, pR_hat = estimate_side_reward_probs(choices_real, rewards_real)

        # pick winning model params
        if winner_AIC == "RW":
            alpha = row['rw_alpha']
            beta = row['rw_beta']
            model_name = "RW"

        else:
            alpha = row['sp_alpha']
            beta = row['sp_beta']
            model_name = "SP"

        measures_real = compute_behavioral_measures(choices_real, rewards_real)

        measures_sim_list = []
        for _ in range(n_simulations):
            if model_name == "RW":
                choices_sim, rewards_sim = simulate_RW_stationary(
                    alpha, beta,
                    n_trials=len(choices_real),
                    pL=pL_hat, pR=pR_hat
                )
            else:
                choices_sim, rewards_sim = simulate_SP_stationary(
                    alpha, beta,
                    n_trials=len(choices_real),
                    pL=pL_hat, pR=pR_hat
                )

            measures_sim = compute_behavioral_measures(choices_sim, rewards_sim)
            measures_sim_list.append(measures_sim)


        measures_sim_avg = {}
        for key in measures_real.keys():
            measures_sim_avg[key] = np.mean([m[key] for m in measures_sim_list])

        result = {
            'dataset_idx': dataset_idx,
            'session_idx': session_idx,
            'task': task,

            'winning_model': model_name,
            'n_trials': len(choices_real),
        }


        for key in measures_real.keys():


            result[f'real_{key}'] = measures_real[key]
            result[f'sim_{key}'] = measures_sim_avg[key]
            result[f'error_{key}'] = abs(measures_real[key] - measures_sim_avg[key])

        validation_results.append(result)

    pbar.close()

    if len(validation_results) == 0:
        return None

    df_val = pd.DataFrame(validation_results)


    measure_keys = ['prop_right', 'win_stay_rate', 'lose_shift_rate',
                    'reward_rate', 'switch_rate', 'mean_run_length']

    correlations = {}
    for key in measure_keys:
        real_col = f'real_{key}'
        sim_col = f'sim_{key}'
        if real_col in df_val.columns and sim_col in df_val.columns:
            r, p = pearsonr(df_val[real_col], df_val[sim_col])
            correlations[key] = {'r': r, 'p': p}
            print(f"{key:20s}: r = {r:.3f}, p = {p:.4f}")

    # comparison plots
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.ravel()

    for i, key in enumerate(measure_keys[:6]):

        real_col = f'real_{key}'
        sim_col = f'sim_{key}'


        if real_col in df_val.columns and sim_col in df_val.columns:
            ax = axes[i]
            ax.scatter(df_val[real_col], df_val[sim_col], alpha=0.5, s=20)

            min_val = min(df_val[real_col].min(), df_val[sim_col].min())
            max_val = max(df_val[real_col].max(), df_val[sim_col].max())
            ax.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=1)

            r = correlations.get(key, {}).get('r', 0)
            ax.set_xlabel(f'Real {key}')
            ax.set_ylabel(f'Simulated {key}')
            ax.set_title(f'{key} (r = {r:.3f})')
            ax.grid(True, alpha=0.3)

    plt.tight_layout()
    fname = "figs/model_validation.png"

    plt.savefig(fname, dpi=220, bbox_inches="tight")
    plt.show()

    print(f"\nSaved: {fname}")

    output_path = "figs/model_validation_results.csv"
    df_val.to_csv(output_path, index=False)

    print(f"Saved validation results to: {output_path}")

    return df_val

# run validation
if 'real_data_results' in globals() and real_data_results is not None:
    validation_results = model_validation(real_data_results)
# Out:
#   Dataset 0: DAWH task, 49 sessions
#   Dataset 1: TAB task, 32 sessions
#   Dataset 2: TAB task, 122 sessions
#   Dataset 3: DAWH task, 38 sessions
#   Dataset 4: DAWH task, 81 sessions
#   Dataset 5: TAB task, 61 sessions
# Validating models: 100%|██████████| 383/383 [00:06<00:00, 57.16session/s]
# prop_right          : r = -0.416, p = 0.0000
# win_stay_rate       : r = 0.896, p = 0.0000
# lose_shift_rate     : r = 0.758, p = 0.0000
# reward_rate         : r = 0.963, p = 0.0000
# switch_rate         : r = 0.872, p = 0.0000
# mean_run_length     : r = 0.792, p = 0.0000
# Saved: figs/model_validation.png
# Saved validation results to: figs/model_validation_results.csv

# %%
#debug check for reward rate
def simulate_RW_trace(alpha, beta, n_trials=200, task="TAB", **task_kwargs):

    A_L, A_R = 0.5, 0.5
    choices = np.zeros(n_trials, dtype=int)
    rewards = np.zeros(n_trials, dtype=int)
    vals_L = np.zeros(n_trials)
    vals_R = np.zeros(n_trials)

    base= task_kwargs.get("base", 0.05)
    inc = task_kwargs.get("inc", 0.08)
    max_p = task_kwargs.get("max_p", 0.95)
    block_len = task_kwargs.get("block_len", 40)
    high, low = 0.8, 0.2
    since_L, since_R = 0, 0

    # log current values
    for t in range(n_trials):

        vals_L[t] = A_L
        vals_R[t] = A_R

        p_right = softmax_prob(A_L, A_R, beta)
        a = RNG.binomial(1, p_right)
        choices[t] = a

        # environment pick
        if task == "TAB":
            pL, pR = simulate_env_TAB_prob(t, block_len, high, low)

        elif task == "DAWH":
            pL = daw_prob(base, inc, since_L, max_p)
            pR = daw_prob(base, inc, since_R, max_p)

        else:
            raise ValueError("Value error")

        # reward
        p = pR if a == 1 else pL
        r = RNG.binomial(1, p)
        rewards[t] = r

        #0 is left
        if a == 0:
            A_L = (1.0 - alpha) * A_L + alpha * r
            since_L = 0
            since_R += 1


        else:
            A_R = (1.0 - alpha) * A_R + alpha * r
            since_R = 0
            since_L += 1


    return choices, rewards, vals_L, vals_R

#sp test w values
def simulate_SP_trace(alpha, beta, n_trials=200, task="DAWH", **task_kwargs):

    A_L, A_R = 0.5, 0.5
    choices = np.zeros(n_trials, dtype=int)
    rewards = np.zeros(n_trials, dtype=int)

    vals_L = np.zeros(n_trials)
    vals_R = np.zeros(n_trials)

    base = task_kwargs.get("base", 0.05)
    inc = task_kwargs.get("inc", 0.08)
    max_p= task_kwargs.get("max_p", 0.95)
    block_len = task_kwargs.get("block_len", 40)

    high, low = 0.8, 0.2
    run_length_L = 0
    run_length_R = 0

    #stacked parameters
    for t in range(n_trials):

        X_L = compute_stack_parameter(A_L, run_length_R)
        X_R = compute_stack_parameter(A_R, run_length_L)

        S_L = A_L * X_L
        S_R = A_R * X_R

        vals_L[t] = S_L
        vals_R[t] = S_R

        # choice
        p_right = softmax_prob(S_L, S_R, beta)
        a = RNG.binomial(1, p_right)
        choices[t] = a

        # environment decision
        if task == "TAB":
            pL, pR = simulate_env_TAB_prob(t, block_len, high, low)

        elif task == "DAWH":
            since_L = run_length_R
            since_R = run_length_L

            pL = daw_prob(base, inc, since_L, max_p)
            pR = daw_prob(base, inc, since_R, max_p)

        else:
            raise ValueError("Value Error")


        p = pR if a == 1 else pL
        r = RNG.binomial(1, p)
        rewards[t] = r


        if a == 0:
            A_L = (1.0 - alpha) * A_L + (alpha / X_L) * r
            run_length_L += 1
            run_length_R = 0
        else:
            A_R = (1.0 - alpha) * A_R + (alpha / X_R) * r
            run_length_R += 1
            run_length_L = 0

    return choices, rewards, vals_L, vals_R



row = real_data_results.iloc[0]

dataset_idx = int(row["dataset_idx"])
session_idx = int(row["session_idx"])
task = row["task"]

choices_real, rewards_real, _ = extract_session_data(data, dataset_idx, session_idx)
n_trials = len(choices_real)

env = {"block_len": 40} if task == "TAB" else {"base": 0.02, "inc": 0.12, "max_p": 0.98}

# RW
rw_alpha = row["rw_alpha"]
rw_beta  = row["rw_beta"]
rw_choices, rw_rewards, rw_vals_L, rw_vals_R = simulate_RW_trace(
    rw_alpha, rw_beta, n_trials=n_trials, task=task, **env
)

# SP
sp_alpha = row["sp_alpha"]
sp_beta  = row["sp_beta"]

sp_choices, sp_rewards, sp_vals_L, sp_vals_R = simulate_SP_trace(sp_alpha, sp_beta, n_trials=n_trials, task=task, **env)

fig, axes = plt.subplots(2, 3, figsize=(14, 8), sharex=True)

# RW vals
axes[0, 0].plot(rw_vals_L, label="A_L (RW)")
axes[0, 0].plot(rw_vals_R, label="A_R (RW)")

axes[0, 0].set_ylabel("Value")
axes[0, 0].set_title("RW action values")
axes[0, 0].legend()
axes[0, 0].grid(alpha=0.3)

# RW choice
axes[0, 1].plot(rw_choices, ".", label="choice (1=R,0=L)")
axes[0, 1].set_title("RW choices")
axes[0, 1].set_ylim(-0.1, 1.1)
axes[0, 1].grid(alpha=0.3)

# RW rewards
axes[0, 2].plot(rw_rewards, ".", label="reward")
axes[0, 2].set_title("RW rewards")
axes[0, 2].set_ylim(-0.1, 1.1)
axes[0, 2].grid(alpha=0.3)

# SP vals
axes[1, 0].plot(sp_vals_L, label="S_L (SP)")
axes[1, 0].plot(sp_vals_R, label="S_R (SP)")


axes[1, 0].set_ylabel("Value")
axes[1, 0].set_title("SP effective values")
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

# SP choices
axes[1, 1].plot(sp_choices, ".", label="choice (1=R,0=L)")
axes[1, 1].set_title("SP choices")

axes[1, 1].set_ylim(-0.1, 1.1)
axes[1, 1].grid(alpha=0.3)

# SP rewards
axes[1, 2].plot(sp_rewards, ".", label="reward")
axes[1, 2].set_title("SP rewards")
axes[1, 2].set_ylim(-0.1, 1.1)

axes[1, 2].grid(alpha=0.3)

for ax in axes[-1, :]:
    ax.set_xlabel("Trial")

plt.suptitle(f"Trace check for dataset {dataset_idx}, session {session_idx} ({task} task)")
plt.tight_layout()
plt.show()
